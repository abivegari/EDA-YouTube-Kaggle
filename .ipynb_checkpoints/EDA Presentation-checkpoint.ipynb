# %% [markdown]
# from notebook.services.config import ConfigManager
# cm = ConfigManager()
# cm.update('livereveal', {
#         'scroll': True,
#         'width': "100%",
#         'height': "100%",
# })

# %% [markdown]
# # Exploratory Data Analysis Terhadap YouTube Daily Trending Dataset
# Oleh <u>ABI VEGARI</u>

# %% [markdown]
# ## Datasets Yang Digunakan
# </br></br>
# Datasets yang digunakan adalah datasets video Youtube yang bersumber dari Kaggle dengan link sebagai berikut : <br>https://www.kaggle.com/datasnaek/youtube-new
#
# Datasets ini mencakup 200+ data video yang dianggap mengalami 'daily trending' per harinya oleh YouTube yang diambil sejak
# <b>14 November 2017 - 14 Juni 2018.</b><br>
#
# Datasets yang digunakan dalam eksplorasi adalah negara : <b>
#  - United States (US)</b>
#
# Jenis dari datasets dari ketiga region tersebut adalah sama yaitu : <b>
#  - Data video dengan format .csv <br>
#  - Data kategori dengan format .json</b>

# %% [markdown]
# ## 1. TAHAP AWAL EDA

# %% [markdown]
# ### Import Library Awal

# %% [markdown]
# Import library <b>pandas</b> dan <b>json</b> yang diperlukan untuk membaca datasets .csv dan .json. <br/><br/>

# %%
# Import pandas & json
import pandas as pd
import json as js
from pandas.io.json import json_normalize

# import numpy
import numpy as np

# set option agar float dapat ditampilkan seluruhnya
pd.set_option('float_format', '{:f}'.format)

# %% [markdown]
# ### Load Datasets
# Datasets yang diload adalah sebagai berikut : <b>
# - US_category_id.json
# - USvideos.csv </b>
#
# Datasets tersebut diubah menjadi dataframe terlebih dahulu dengan library Pandas agar dapat diolah.

# %%
#Load datasets US
dfUSVideos = pd.read_csv("datasets/USvideos.csv")
with open("datasets/US_category_id.json") as file:    
    jsUSCategory = js.load(file)

# set option agar float dapat ditampilkan seluruhnya
pd.set_option('float_format', '{:f}'.format)

# %% [markdown]
# ## Dataset Video
# Dataset video terdiri dari kolom sebagai berikut :

# %% [markdown]
# #### Melihat daftar nama kolom

# %%
dfUSVideos.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %% [markdown]
# #### Melihat tipe data dari tiap kolom

# %%
dfUSVideos.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
dfUSVideos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  40949 non-null object
# trending_date             40949 non-null object
# title                     40949 non-null object
# channel_title             40949 non-null object
# category_id               40949 non-null int64
# publish_time              40949 non-null object
# tags                      40949 non-null object
# views                     40949 non-null int64
# likes                     40949 non-null int64
# dislikes                  40949 non-null int64
# comment_count             40949 non-null int64
# thumbnail_link            40949 non-null object
# comments_disabled         40949 non-null bool
# ratings_disabled          40949 non-null bool
# video_error_or_removed    40949 non-null bool
# description               40379 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %% [markdown]
# #### Deskripsi statistik (seharusnya diterapkan pada data angka)

# %%
dfUSVideos.describe()
# Out:
#        category_id            views          likes       dislikes  \
# count 40949.000000     40949.000000   40949.000000   40949.000000
# mean     19.972429   2360784.638257   74266.702435    3711.400889
# std       7.568327   7394113.759704  228885.338209   29029.705945
# min       1.000000       549.000000       0.000000       0.000000
# 25%      17.000000    242329.000000    5424.000000     202.000000
# 50%      24.000000    681861.000000   18091.000000     631.000000
# 75%      25.000000   1823157.000000   55417.000000    1938.000000
# max      43.000000 225211923.000000 5613827.000000 1674420.000000
#
#        comment_count
# count   40949.000000
# mean     8446.803683
# std     37430.486994
# min         0.000000
# 25%       614.000000
# 50%      1856.000000
# 75%      5755.000000
# max   1361580.000000

# %%
dfUSVideos[['views','dislikes']].describe()
# Out:
#                  views       dislikes
# count     40949.000000   40949.000000
# mean    2360784.638257    3711.400889
# std     7394113.759704   29029.705945
# min         549.000000       0.000000
# 25%      242329.000000     202.000000
# 50%      681861.000000     631.000000
# 75%     1823157.000000    1938.000000
# max   225211923.000000 1674420.000000

# %% [markdown]
# #### Melihat dimensi data video

# %%
dfUSVideos.shape
# Out:
# (40949, 16)

# %% [markdown]
# ### Menampilkan / Seleksi Data (Data Video)

# %% [markdown]
# #### Menampilkan potongan data

# %%
dfUSVideos.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
dfUSVideos.tail()
# Out:
#           video_id trending_date  \
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# ...

# %% [markdown]
# #### Menampilkan data berdasarkan nama kolom

# %%
dfUSVideos[['channel_title','description']]
# Out:
#                   channel_title  \
# 0                  CaseyNeistat
# 1               LastWeekTonight
# 2                  Rudy Mancuso
# 3         Good Mythical Morning
# 4                      nigahiga
# ...                         ...
# 40944             AaronsAnimals
# 40945                  zefrank1
# 40946                Brad Mondo
# 40947  How It Should Have Ended
# 40948              Call of Duty
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# ...

# %% [markdown]
# #### Menampilkan data berdasarkan lokasi baris dataframe

# %%
dfUSVideos.iloc[0]
# Out:
# video_id                                                        2kyS6SvSYSE
# trending_date                                                      17.14.11
# title                                    WE WANT TO TALK ABOUT OUR MARRIAGE
# channel_title                                                  CaseyNeistat
# category_id                                                              22
# publish_time                                       2017-11-13T17:13:01.000Z
# tags                                                        SHANtell martin
# views                                                                748374
# likes                                                                 57527
# dislikes                                                               2966
# comment_count                                                         15954
# thumbnail_link               https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# ...

# %% [markdown]
# #### Menampilkan data berdasarkan lokasi kolom dataframe

# %%
dfUSVideos.iloc[:,1]
# Out:
# 0        17.14.11
# 1        17.14.11
# 2        17.14.11
# 3        17.14.11
# 4        17.14.11
#            ...
# 40944    18.14.06
# 40945    18.14.06
# 40946    18.14.06
# 40947    18.14.06
# 40948    18.14.06
# Name: trending_date, Length: 40949, dtype: object

# %% [markdown]
# #### Menampilkan data berdasarkan lokasi baris & kolom dataframe

# %%
dfUSVideos.iloc[0,1]
# Out:
# '17.14.11'

# %% [markdown]
# #### Menampilkan data bedasarkan range baris

# %% [markdown]
# Dimulai dari [0:1] karena walaupun seharusnya ditampilkan dari baris 0 hingga 1 tetapi baris 1 tidak termasuk

# %%
dfUSVideos[0:1]
# Out:
#       video_id trending_date                               title  \
# 0  2kyS6SvSYSE      17.14.11  WE WANT TO TALK ABOUT OUR MARRIAGE
#
#   channel_title  category_id              publish_time             tags  \
# 0  CaseyNeistat           22  2017-11-13T17:13:01.000Z  SHANtell martin
#
#     views  likes  dislikes  comment_count  \
# 0  748374  57527      2966          15954
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
#
#    ratings_disabled  video_error_or_removed  \
# 0             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...

# %% [markdown]
# #### Menampilkan data berdasarkan nilai spesifik

# %%
dfUSVideos.loc[dfUSVideos['channel_title'] == 'CaseyNeistat']
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 217    2kyS6SvSYSE      17.15.11
# 448    2kyS6SvSYSE      17.16.11
# 689    2kyS6SvSYSE      17.17.11
# 924    2kyS6SvSYSE      17.18.11
# ...            ...           ...
# 39982  1HLMi1s6Tho      18.10.06
# 40183  1HLMi1s6Tho      18.11.06
# 40402  1HLMi1s6Tho      18.12.06
# 40606  1HLMi1s6Tho      18.13.06
# 40818  1HLMi1s6Tho      18.14.06
#
#                                                title channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat
# 217               WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat
# 448               WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat
# 689               WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat
# 924               WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat
# ...                                              ...           ...
# 39982  there's something we've been hiding from you.  CaseyNeistat
# ...

# %%
dfUSVideos.loc[dfUSVideos['channel_title'] == 'CaseyNeistat', ['title']]
# Out:
#                                                title
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 217               WE WANT TO TALK ABOUT OUR MARRIAGE
# 448               WE WANT TO TALK ABOUT OUR MARRIAGE
# 689               WE WANT TO TALK ABOUT OUR MARRIAGE
# 924               WE WANT TO TALK ABOUT OUR MARRIAGE
# ...                                              ...
# 39982  there's something we've been hiding from you.
# 40183  there's something we've been hiding from you.
# 40402  there's something we've been hiding from you.
# 40606  there's something we've been hiding from you.
# 40818  there's something we've been hiding from you.
#
# [95 rows x 1 columns]

# %%
dfUSVideos[dfUSVideos['views']<1000]
# Out:
#           video_id trending_date  \
# 42     NZFhMSgbKKM      17.14.11
# 160    qg0GdM60syI      17.14.11
# 546    -JVITToppE0      17.16.11
# 777    -JVITToppE0      17.17.11
# 1114   g3VgrgV3kFk      17.19.11
# 1339   g3VgrgV3kFk      17.20.11
# 10704  Wwyxaow1wWg      18.06.01
# 10902  s_FAjI51LPU      18.07.01
# 11103  JNv4w6DFoYs      18.08.01
# 11329  JNv4w6DFoYs      18.09.01
# 11710  TKMXw1YI5S4      18.13.01
# 11924  TKMXw1YI5S4      18.14.01
# 12156  TKMXw1YI5S4      18.15.01
# 12371  TKMXw1YI5S4      18.16.01
# 12716  zeQaJGkFyqQ      18.18.01
# 12961  tKX8nUCSBjM      18.19.01
# 13145  jiP82WVx6mM      18.20.01
# 13187  tKX8nUCSBjM      18.20.01
# 13398  tKX8nUCSBjM      18.21.01
# 14335  y6KYFcta4SE      18.26.01
# 14531  dQMZLXaa1L8      18.27.01
# 14563  y6KYFcta4SE      18.27.01
# 14750  dQMZLXaa1L8      18.28.01
# 14782  y6KYFcta4SE      18.28.01
# 14816  S_HixQBiVH0      18.29.01
# 14984  dQMZLXaa1L8      18.29.01
#
# ...

# %% [markdown]
# ### Mengecek NaN Pada Dataframe
# Untuk mengecek ada tidaknya Not a Number (NaN) pada dataframe dengan <b>isna()</b> atau isnull() .

# %% [markdown]
# #### Mengecek NaN pada keseluruhan dataframe

# %%
dfUSVideos.isna().any()
# Out:
# video_id                  False
# trending_date             False
# title                     False
# channel_title             False
# category_id               False
# publish_time              False
# tags                      False
# views                     False
# likes                     False
# dislikes                  False
# comment_count             False
# thumbnail_link            False
# comments_disabled         False
# ratings_disabled          False
# video_error_or_removed    False
# description                True
# dtype: bool

# %% [markdown]
# #### Mengecek ada tidaknya NaN pada suatu kolom (kolom 'description')

# %%
dfUSVideos['description'].isna().any()
# Out:
# True

# %% [markdown]
# #### Mengecek jumlah NaN pada suatu kolom (kolom 'description')

# %%
dfUSVideos['description'].isna().sum()
# Out:
# 570

# %% [markdown]
# #### Menampilkan data yang mengandung NaN pada suatu kolom (kolom 'description')

# %%
dfUSVideos[dfUSVideos['description'].isna()]
# Out:
#           video_id trending_date  \
# 42     NZFhMSgbKKM      17.14.11
# 47     sbcbvuitiTc      17.14.11
# 175    4d07RXYLsJE      17.14.11
# 267    NZFhMSgbKKM      17.15.11
# 312    sbcbvuitiTc      17.15.11
# ...            ...           ...
# 40125  1h7KV2sjUWY      18.10.06
# 40325  1h7KV2sjUWY      18.11.06
# 40538  1h7KV2sjUWY      18.12.06
# 40739  1h7KV2sjUWY      18.13.06
# 40945  1h7KV2sjUWY      18.14.06
#
#                                                    title  \
# 42     Dennis Smith Jr. and LeBron James go back and ...
# 47     Stephon Marbury and Jimmer Fredette fight in C...
# 175                  Sphaera - demonstrating interaction
# 267    Dennis Smith Jr. and LeBron James go back and ...
# 312    Stephon Marbury and Jimmer Fredette fight in C...
# ...                                                  ...
# 40125                         True Facts : Ant Mutualism
# 40325                         True Facts : Ant Mutualism
# ...

# %% [markdown]
# ### Mengisi atau Menghapus NaN Sesuai Kebutuhan Jika Diperlukan
# NaN dapat diisi sesuai keingingan apabila memang diperlukan dengan menggunakan <b>.fillna()</b>

# %% [markdown]
# #### Menghapus NaN

# %%
dfTestDrop = dfUSVideos.dropna(how='all')

# %%
dfTestDrop
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
dfTestDrop['description'].isna().any()
# Out:
# True

# %% [markdown]
# #### Mengisi NaN

# %%
dfUSVideos["description"].fillna(value="None")
# Out:
# 0        SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1        One year after the presidential election, John...
# 2        WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3        Today we find out if Link is a Nickelback amat...
# 4        I know it's been a while since we did this sho...
#                                ...
# 40944       The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                 None
# 40946    I had so much fun transforming Safiyas hair in...
# 40947    How Black Panther Should Have EndedWatch More ...
# 40948    Call of Duty: Black Ops 4 Multiplayer raises t...
# Name: description, Length: 40949, dtype: object

# %%
dfUSVideos['description'].isna().any()
# Out:
# True

# %% [markdown]
# ### Melihat Korelasi Antar Kolom pada Dataframe

# %%
dfUSVideos.corr()
# Out:
#                         category_id     views     likes  dislikes  \
# category_id                1.000000 -0.168231 -0.173921 -0.033547
# views                     -0.168231  1.000000  0.849177  0.472213
# likes                     -0.173921  0.849177  1.000000  0.447186
# dislikes                  -0.033547  0.472213  0.447186  1.000000
# comment_count             -0.076307  0.617621  0.803057  0.700184
# comments_disabled          0.048949  0.002677 -0.028918 -0.004431
# ratings_disabled          -0.013506  0.015355 -0.020888 -0.008230
# video_error_or_removed    -0.030011 -0.002256 -0.002641 -0.001853
#
#                         comment_count  comments_disabled  ratings_disabled  \
# category_id                 -0.076307           0.048949         -0.013506
# views                        0.617621           0.002677          0.015355
# likes                        0.803057          -0.028918         -0.020888
# ...

# %% [markdown]
# ### Menemukan Jumlah Video Yang Trending Per Hari
# Menurut klaim seharusnya ada up to 200 data video yang trending per harinya

# %%
dfUSVideos['trending_date']
# Out:
# 0        17.14.11
# 1        17.14.11
# 2        17.14.11
# 3        17.14.11
# 4        17.14.11
#            ...
# 40944    18.14.06
# 40945    18.14.06
# 40946    18.14.06
# 40947    18.14.06
# 40948    18.14.06
# Name: trending_date, Length: 40949, dtype: object

# %% [markdown]
# #### Mengubah tipe data dari object menjadi datetime

# %% [markdown]
# Kolom <b>'trending_date'</b> harus dijadikan ke dalam bentuk datetime terlebih dahulu

# %%
dfUSVideos['trending_date'] =  pd.to_datetime(dfUSVideos['trending_date'], format='%y.%d.%m')

# %% [markdown]
# #### Mengelompokkan data
# Pengelompokkan data dengan function groupby()

# %%
group = dfUSVideos.groupby('channel_title')

# %%
group

# %%
group.get_group("ESPN")
# Out:
#           video_id trending_date  \
# 193    agKDPntMv-E    2017-11-14
# 220    KJ12FVmumeA    2017-11-15
# 447    KJ12FVmumeA    2017-11-16
# 659    uN9zBcweN4M    2017-11-17
# 894    uN9zBcweN4M    2017-11-18
# ...            ...           ...
# 39963  btE8mDfEF34    2018-06-10
# 40165  btE8mDfEF34    2018-06-11
# 40363  3tYpfAPVEs0    2018-06-12
# 40570  3tYpfAPVEs0    2018-06-13
# 40761  JGm9Y_hFqNk    2018-06-14
#
#                                                    title channel_title  \
# 193    Stephen A. Smith slams the Philadelphia 76ers ...          ESPN
# 220    Stephen A. Smith: Jay Cutler is a 'disease' | ...          ESPN
# 447    Stephen A. Smith: Jay Cutler is a 'disease' | ...          ESPN
# 659    NBA Countdown debates if Ben Simmons is the be...          ESPN
# 894    NBA Countdown debates if Ben Simmons is the be...          ESPN
# ...                                                  ...           ...
# ...

# %%
group.get_group("ESPN").views.mean()
# Out:
# 520464.12807881774

# %%
dfUSVideos.loc[dfUSVideos['channel_title'] == 'ESPN'].views.mean()
# Out:
# 520464.12807881774

# %% [markdown]
# #### Mengelompokkan kolom 'trending_date'

# %% [markdown]
# Grouping dilakukan berdasarkan kolom <b>'trending_date'</b>, kemudian dilakukan count untuk mengetahui berapa row data dalam satu hari trending_date

# %%
#membuat dataframe baru dengan count yang menghitung berapa row data muncul berdasarkan trending_date pada datasets df videos
dfUSPerDay = pd.DataFrame(dfUSVideos.groupby('trending_date').count().reset_index())

dfUSPerDay.head()
# Out:
#   trending_date  video_id  title  channel_title  category_id  publish_time  \
# 0    2017-11-14       200    200            200          200           200
# 1    2017-11-15       200    200            200          200           200
# 2    2017-11-16       200    200            200          200           200
# 3    2017-11-17       200    200            200          200           200
# 4    2017-11-18       200    200            200          200           200
#
#    tags  views  likes  dislikes  comment_count  thumbnail_link  \
# 0   200    200    200       200            200             200
# 1   200    200    200       200            200             200
# 2   200    200    200       200            200             200
# 3   200    200    200       200            200             200
# 4   200    200    200       200            200             200
#
#    comments_disabled  ratings_disabled  video_error_or_removed  description
# ...

# %% [markdown]
# #### Memilih data tertentu yang ingin ditampilkan dengan filter sebagai alternatif loc & iloc (kolom 'trending_date' & 'video_id')

# %%
#dilakukan filtering karena hanya membutuhkan 2 kolom saja
dfUSPerDay = dfUSPerDay.filter(['trending_date', 'video_id'])

#rename kolom menjadi counter
dfUSPerDay.columns = ['trending_date', 'counter']

dfUSPerDay.head(5)
# Out:
#   trending_date  counter
# 0    2017-11-14      200
# 1    2017-11-15      200
# 2    2017-11-16      200
# 3    2017-11-17      200
# 4    2017-11-18      200

# %% [markdown]
# ### Jumlah Video Per Hari

# %% [markdown]
# #### Mengetahui Nilai Terkecil dari Suatu Kolom (di sini kolom counter)

# %%
dfUSPerDay["counter"].min()
# Out:
# 196

# %% [markdown]
# #### Mengetahui Nilai Terbesar dari Suatu Kolom (di sini kolom counter)

# %%
dfUSPerDay["counter"].max()
# Out:
# 200

# %% [markdown]
# #### Mengetahui Nilai Rata-rata dari Suatu Kolom (di sini kolom counter)

# %%
dfUSPerDay["counter"].mean()
# Out:
# 199.75121951219512

# %% [markdown]
# ### Menemukan Lama Perekaman Data Video
# Menurut klaim seharusnya data diambil sejak 14 November 2017 hingga 14 Juni 2018

# %%
dfUSVideos['trending_date'].min()
# Out:
# Timestamp('2017-11-14 00:00:00')

# %%
dfUSVideos['trending_date'].max()
# Out:
# Timestamp('2018-06-14 00:00:00')

# %% [markdown]
# ### Mengubah Index (Transformasi Dataframe)
# Pengubahan Index pada dataframe dapat dilakukan dengan banyak cara & dimaksudkan agar dapat melihat dataframe dari sudut pandang yang berbeda.

# %% [markdown]
# #### Penggunaan set_index()

# %%
dfUSVideos.head(3)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
#
#                                                title    channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...  LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...     Rudy Mancuso
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
#
#    dislikes  comment_count                                  thumbnail_link  \
# ...

# %%
dfTestIndex = dfUSVideos.set_index('channel_title')
dfTestIndex
# Out:
#                              video_id trending_date  \
# channel_title
# CaseyNeistat              2kyS6SvSYSE    2017-11-14
# LastWeekTonight           1ZAPwfrtAFY    2017-11-14
# Rudy Mancuso              5qpjK5DgCt4    2017-11-14
# Good Mythical Morning     puqaWrEC7tY    2017-11-14
# nigahiga                  d380meD0W0M    2017-11-14
# ...                               ...           ...
# AaronsAnimals             BZt0qjTWNhw    2018-06-14
# zefrank1                  1h7KV2sjUWY    2018-06-14
# Brad Mondo                D6Oy4LfoqsU    2018-06-14
# How It Should Have Ended  oV0zkMe1K8s    2018-06-14
# Call of Duty              ooyjaVdt-jA    2018-06-14
#
#                                                                       title  \
# channel_title
# CaseyNeistat                             WE WANT TO TALK ABOUT OUR MARRIAGE
# LastWeekTonight           The Trump Presidency: Last Week Tonight with J...
# Rudy Mancuso              Racist Superman | Rudy Mancuso, King Bach & Le...
# ...

# %% [markdown]
# #### Menampilkan data dengan loc

# %%
dfTestIndex.loc['ESPN']
# Out:
#                   video_id trending_date  \
# channel_title
# ESPN           agKDPntMv-E    2017-11-14
# ESPN           KJ12FVmumeA    2017-11-15
# ESPN           KJ12FVmumeA    2017-11-16
# ESPN           uN9zBcweN4M    2017-11-17
# ESPN           uN9zBcweN4M    2017-11-18
# ...                    ...           ...
# ESPN           btE8mDfEF34    2018-06-10
# ESPN           btE8mDfEF34    2018-06-11
# ESPN           3tYpfAPVEs0    2018-06-12
# ESPN           3tYpfAPVEs0    2018-06-13
# ESPN           JGm9Y_hFqNk    2018-06-14
#
#                                                            title  category_id  \
# channel_title
# ESPN           Stephen A. Smith slams the Philadelphia 76ers ...           17
# ESPN           Stephen A. Smith: Jay Cutler is a 'disease' | ...           17
# ESPN           Stephen A. Smith: Jay Cutler is a 'disease' | ...           17
# ESPN           NBA Countdown debates if Ben Simmons is the be...           17
# ...

# %% [markdown]
# #### Contoh Pemanfaatan pivot() & pivot_table()
# Pivot dapat digunakan apabila ingin menentukan data yang ada di baris dan di kolom. Komposisi data perlu diperhatikan saat melakukan pivot. <b>
# Pivot tidak dapat dilakukan apabila pasangan index/kolomnya tidak unik</b>.

# %%
dfPivot = dfUSVideos[['trending_date','title','likes', 'dislikes']].head(1000)

# %%
dfPivot
# Out:
#     trending_date                                              title   likes  \
# 0      2017-11-14                 WE WANT TO TALK ABOUT OUR MARRIAGE   57527
# 1      2017-11-14  The Trump Presidency: Last Week Tonight with J...   97185
# 2      2017-11-14  Racist Superman | Rudy Mancuso, King Bach & Le...  146033
# 3      2017-11-14                   Nickelback Lyrics: Real or Fake?   10172
# 4      2017-11-14                           I Dare You: GOING BALD!?  132235
# ..            ...                                                ...     ...
# 995    2017-11-18         Eminem - Walk On Water (Audio) ft. Beyoncé  911883
# 996    2017-11-18                              Darth Vader Mask Fail    3676
# 997    2017-11-18  Donald Trump makes ASEAN handshake photo op go...      40
# 998    2017-11-18  Why a New York Ice Cream Shop is Releasing Ham...     627
# 999    2017-11-18        Amazon Christmas Advert 2017 - Toys & Games     232
#
#      dislikes
# 0        2966
# ...

# %%
dfPivot.pivot(index = "title", columns = "trending_date")
# Out:
#                                                           likes               \
# trending_date                                        2017-11-14   2017-11-15
# title
# #StarOnFox Exclusive Clip for TheYBF.com                    nan          nan
# #VeteransDay: Thank You for Everything             26917.000000 27068.000000
# 'Lightning Strike' B777-300 on departure @ KL74...          nan   386.000000
# 'Lord of the Rings' TV Series Gets Multi-Season...          nan    47.000000
# (SPOILERS) 'Shiva Saves the Day' Talked About S...  1576.000000  2279.000000
# ...                                                         ...          ...
# dapulse is now monday.com. And there's a good r...          nan    17.000000
# funfetti is extremely fun                                   nan 12229.000000
# iPhone X vs Makeup Transformation (Face ID TEST)   33505.000000 37124.000000
# venting online about a hard part in a video game            nan 25188.000000
# ...

# %% [markdown]
# Jika pasangan index/kolomnya tidak unik bisa coba memanfaatkan pivot_table(). <br>Tetapi pivot_table() di sini akan menampilkan summary secara keseluruhan.

# %%
dfPivot.pivot_table(index = "trending_date", columns = "title") # defaultnya adalah summary rata-rata/mean
# dfPivot.pivot_table(index = "trending_date", columns = "category_id", aggfunc = "mean") # sum
# Out:
#                                               dislikes  \
# title         #StarOnFox Exclusive Clip for TheYBF.com
# trending_date
# 2017-11-14                                         nan
# 2017-11-15                                         nan
# 2017-11-16                                         nan
# 2017-11-17                                         nan
# 2017-11-18                                    0.000000
#
#                                                       \
# title         #VeteransDay: Thank You for Everything
# trending_date
# 2017-11-14                               1979.000000
# 2017-11-15                               2021.000000
# 2017-11-16                               2042.000000
# 2017-11-17                                       nan
# 2017-11-18                                       nan
#
#                                                                           \
# title         'Lightning Strike' B777-300 on departure @ KL743 // PH-BVS
# trending_date
# ...

# %% [markdown]
# ### Contoh Pemanfaatan Melt
# Melt pada dataframe akan mengubah bentuk dataframe menjadi variabel dan value dari variabel.

# %%
dfMelt = dfUSVideos[['title','likes','dislikes']].head(100)

# %%
dfMelt
# Out:
#                                                 title   likes  dislikes
# 0                  WE WANT TO TALK ABOUT OUR MARRIAGE   57527      2966
# 1   The Trump Presidency: Last Week Tonight with J...   97185      6146
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...  146033      5339
# 3                    Nickelback Lyrics: Real or Fake?   10172       666
# 4                            I Dare You: GOING BALD!?  132235      1989
# ..                                                ...     ...       ...
# 95   Kimbra - Top of the World (Official Music Video)    8599       361
# 96  Camila Cabello COMPLETELY NAILS 'Finish The Ly...   40195       373
# 97  Edna's registered owner thought she was dead f...   16396        81
# 98      When Someone Has A Crush on You | Lilly Singh  202676      3394
# 99       Neck Deep - Parachute (Official Music Video)   14338       171
#
# [100 rows x 3 columns]

# %%
dfMelt1 = pd.melt(dfMelt, id_vars=['title'])

# %%
dfMelt1
# Out:
#                                                  title  variable   value
# 0                   WE WANT TO TALK ABOUT OUR MARRIAGE     likes   57527
# 1    The Trump Presidency: Last Week Tonight with J...     likes   97185
# 2    Racist Superman | Rudy Mancuso, King Bach & Le...     likes  146033
# 3                     Nickelback Lyrics: Real or Fake?     likes   10172
# 4                             I Dare You: GOING BALD!?     likes  132235
# ..                                                 ...       ...     ...
# 195   Kimbra - Top of the World (Official Music Video)  dislikes     361
# 196  Camila Cabello COMPLETELY NAILS 'Finish The Ly...  dislikes     373
# 197  Edna's registered owner thought she was dead f...  dislikes      81
# 198      When Someone Has A Crush on You | Lilly Singh  dislikes    3394
# 199       Neck Deep - Parachute (Official Music Video)  dislikes     171
#
# [200 rows x 3 columns]

# %%
dfMelt1 = pd.melt(dfMelt, id_vars=['title'], var_name="keterangan", value_name="nilai")

# %%
dfMelt1
# Out:
#                                                  title keterangan   nilai
# 0                   WE WANT TO TALK ABOUT OUR MARRIAGE      likes   57527
# 1    The Trump Presidency: Last Week Tonight with J...      likes   97185
# 2    Racist Superman | Rudy Mancuso, King Bach & Le...      likes  146033
# 3                     Nickelback Lyrics: Real or Fake?      likes   10172
# 4                             I Dare You: GOING BALD!?      likes  132235
# ..                                                 ...        ...     ...
# 195   Kimbra - Top of the World (Official Music Video)   dislikes     361
# 196  Camila Cabello COMPLETELY NAILS 'Finish The Ly...   dislikes     373
# 197  Edna's registered owner thought she was dead f...   dislikes      81
# 198      When Someone Has A Crush on You | Lilly Singh   dislikes    3394
# 199       Neck Deep - Parachute (Official Music Video)   dislikes     171
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Dataset Kategori
# Karena dataset berformat .json maka perlu dilakukan transformasi untuk mengubahnya menjadi dataframe.

# %%
jsUSCategory
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJvJAAShlR6hM"',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKmPBggty2mZQ"',
#    'id': '1',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Film & Animation',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#    'id': '2',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Autos & Vehicles',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#    'id': '10',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Music',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-oBJavSGkfDI"',
#    'id': '15',
# ...

# %% [markdown]
# ### Normalisasi list items di data kategori
# Karena yang dibutuhkan adalah id dan title di dalam list items, maka items harus dinormalisasi dengan menggunakan sintaks <b>json_normalize()</b>.
# Dengan json_normalize, Pandas dapat mengambil objek JSON yang bersarang dan mengubahnya menjadi dataframe.

# %%
dfUSCategoryJson = json_normalize(jsUSCategory['items'])

# %%
dfUSCategoryJson.head()
# Out:
#                     kind                                               etag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#
#    id         snippet.channelId     snippet.title  snippet.assignable
# 0   1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation                True
# 1   2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles                True
# 2  10  UCBR8-60-B28hp2BmDPdntcQ             Music                True
# 3  15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals                True
# 4  17  UCBR8-60-B28hp2BmDPdntcQ            Sports                True

# %% [markdown]
# ### Mengubah Data Kategori Menjadi ID dan Nama Kategori Saja
# ID dan nama category/snippet title dibutuhkan untuk dimerge dengan dataframe video. Maka harus dilakukan drop pada kolom yang tidak diperlukan pada dataframe.

# %%
dfUSCategoryJson.drop(['etag','kind','snippet.assignable','snippet.channelId'], axis=1, inplace=True)

# %% [markdown]
# kolom snippet.title direname menjadi title agar tidak membingungkan.

# %%
dfUSCategoryJson.rename(columns={'id' : 'category_id', 'snippet.title': 'category'}, inplace=True)

# %% [markdown]
# ### Data Kategori (Berdasarkan data kategori .json)

# %%
dfUSCategoryJson
# Out:
#    category_id               category
# 0            1       Film & Animation
# 1            2       Autos & Vehicles
# 2           10                  Music
# 3           15         Pets & Animals
# 4           17                 Sports
# 5           18           Short Movies
# 6           19        Travel & Events
# 7           20                 Gaming
# 8           21          Videoblogging
# 9           22         People & Blogs
# 10          23                 Comedy
# 11          24          Entertainment
# 12          25        News & Politics
# 13          26          Howto & Style
# 14          27              Education
# 15          28   Science & Technology
# 16          29  Nonprofits & Activism
# 17          30                 Movies
# 18          31        Anime/Animation
# 19          32       Action/Adventure
# 20          33               Classics
# 21          34                 Comedy
# 22          35            Documentary
# 23          36                  Drama
# ...

# %% [markdown]
# ### Membuat Data Kategori Sesuai Dengan ID Kategori Yang Ditemukan di Dataframe Video

# %% [markdown]
# Dataframe video seperti diketahui sebelumnya memiliki kolom <b>'category_id'</b>.<br/>
# Tetapi, dataframe video tidak memiliki kolom nama kategori. Agar dapat mengetahui kategori-kategori apa saja yang terdapat pada data-data video akan dibuat dataframe baru yang menyatukan kolom 'category_id' pada dataframe video dengan kolom 'category' pada dataframe kategori.

# %%
dfUSVideos.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %% [markdown]
# ### Menemukan ID Kategori Unik dari Tiap Dataframe Video
# Dilakukan fungsi unique() pada kolom <b>'category_id'</b> pada dataframe video untuk dapat mengetahui ID kategori apa saja yang terdapat pada dataframe video masing-masing negara.</br>
#
# Berikut adalah contoh yang dilakukan pada dataframe video Canada.

# %%
dfUSVideos.category_id.unique()
# Out:
# array([22, 24, 23, 28,  1, 25, 17, 10, 15, 27, 26,  2, 19, 20, 29, 43],
#       dtype=int64)

# %% [markdown]
# #### Masukkan Array ke Dalam Penampung Sementara

# %% [markdown]
# Array unique() dijadikan dataframe sementara dengan nama kolom 'id' dan dibuat dalam bentuk dictionary.

# %%
dfUSCategoryVid = pd.DataFrame({'category_id' : dfUSVideos.category_id.unique()})

# %%
dfUSCategoryVid
# Out:
#     category_id
# 0            22
# 1            24
# 2            23
# 3            28
# 4             1
# 5            25
# 6            17
# 7            10
# 8            15
# 9            27
# 10           26
# 11            2
# 12           19
# 13           20
# 14           29
# 15           43

# %% [markdown]
# #### Melakukan Sortir Dari ID Kategori terendah

# %%
# sortir berdasarkan kolom 'id'
dfUSCategoryVid.sort_values(by='category_id', inplace=True)

# %%
# reset index agar index dibuat ulang dari urutan 0
dfUSCategoryVid.reset_index(drop=True, inplace=True)

# %%
dfUSCategoryVid
# Out:
#     category_id
# 0             1
# 1             2
# 2            10
# 3            15
# 4            17
# 5            19
# 6            20
# 7            22
# 8            23
# 9            24
# 10           25
# 11           26
# 12           27
# 13           28
# 14           29
# 15           43

# %% [markdown]
# ### Penyatuan Data Kategori Sementara dengan Data Kategori yang dibuat dari .json
# Penyatuan dilakukan agar kita dapat mengetahui ID kategori dan nama kategorinya dalam 1 buah dataframe. Penyatuan dilakukan dengan fungsi <b>merge()</b> antara dataframe berikut :
# <b>
#  - dfUSCategoryVid <=> dfUSCategoryJson
# </b>

# %%
dfUSCategoryJson
# Out:
#    category_id               category
# 0            1       Film & Animation
# 1            2       Autos & Vehicles
# 2           10                  Music
# 3           15         Pets & Animals
# 4           17                 Sports
# 5           18           Short Movies
# 6           19        Travel & Events
# 7           20                 Gaming
# 8           21          Videoblogging
# 9           22         People & Blogs
# 10          23                 Comedy
# 11          24          Entertainment
# 12          25        News & Politics
# 13          26          Howto & Style
# 14          27              Education
# 15          28   Science & Technology
# 16          29  Nonprofits & Activism
# 17          30                 Movies
# 18          31        Anime/Animation
# 19          32       Action/Adventure
# 20          33               Classics
# 21          34                 Comedy
# 22          35            Documentary
# 23          36                  Drama
# ...

# %%
dfUSCategoryVid
# Out:
#     category_id
# 0             1
# 1             2
# 2            10
# 3            15
# 4            17
# 5            19
# 6            20
# 7            22
# 8            23
# 9            24
# 10           25
# 11           26
# 12           27
# 13           28
# 14           29
# 15           43

# %% [markdown]
# Sebelum disatukan kolom 'id' pada dataframe kategori yang dibuat dari .json adalah bertipe object. Agar dapat disatukan dengan dataframe kategori sementara, kolom tersebut harus diubah menjadi int64 agar sama dengan kolom 'id' pada dataframe kategori sementara.

# %%
dfUSCategoryJson["category_id"].dtypes
# Out:
# dtype('O')

# %%
dfUSCategoryVid["category_id"].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# Pengubahan dilakukan dengan fungsi astype()

# %%
dfUSCategoryJson["category_id"] = dfUSCategoryJson["category_id"].astype('int64')

# %%
dfUSCategoryJson["category_id"].dtypes
# Out:
# dtype('int64')

# %%
# penyatuan didasarkan pada kolom 'id'
dfUSCategoryVid = pd.merge(dfUSCategoryVid, dfUSCategoryJson, on="category_id", how='left')

# %%
dfUSCategoryVid
# Out:
#     category_id               category
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            19        Travel & Events
# 6            20                 Gaming
# 7            22         People & Blogs
# 8            23                 Comedy
# 9            24          Entertainment
# 10           25        News & Politics
# 11           26          Howto & Style
# 12           27              Education
# 13           28   Science & Technology
# 14           29  Nonprofits & Activism
# 15           43                  Shows

# %% [markdown]
# ### Data Kategori (Berdasarkan Data Video)

# %%
dfUSCategoryVid
# Out:
#     category_id               category
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            19        Travel & Events
# 6            20                 Gaming
# 7            22         People & Blogs
# 8            23                 Comedy
# 9            24          Entertainment
# 10           25        News & Politics
# 11           26          Howto & Style
# 12           27              Education
# 13           28   Science & Technology
# 14           29  Nonprofits & Activism
# 15           43                  Shows

# %% [markdown]
# ### Penyatuan / Merge Lainnya

# %%
# Penyatuan mirip seperti SQL

dfMerge = pd.merge(dfUSCategoryVid, dfUSCategoryJson, on="category_id")
# dfMerge = pd.merge(dfUSCategoryVid, dfUSCategoryJson, on="category_id", how="outer") # penyatuan gabungan
# dfMerge = pd.merge(dfUSCategoryVid, dfUSCategoryJson, on="category_id", how="right") # right join

# %%
dfMerge
# Out:
#     category_id             category_x             category_y
# 0             1       Film & Animation       Film & Animation
# 1             2       Autos & Vehicles       Autos & Vehicles
# 2            10                  Music                  Music
# 3            15         Pets & Animals         Pets & Animals
# 4            17                 Sports                 Sports
# 5            19        Travel & Events        Travel & Events
# 6            20                 Gaming                 Gaming
# 7            22         People & Blogs         People & Blogs
# 8            23                 Comedy                 Comedy
# 9            24          Entertainment          Entertainment
# 10           25        News & Politics        News & Politics
# 11           26          Howto & Style          Howto & Style
# 12           27              Education              Education
# 13           28   Science & Technology   Science & Technology
# ...

# %% [markdown]
# ### Perbedaan Data Kategori (Berdasarkan Data Video vs. Data .JSON)

# %%
dfUSCategoryVid.equals(dfUSCategoryJson)
# Out:
# False

# %% [markdown]
# Usahakan Concat dilakukan pada dataframe yang memiliki jumlah & nama kolom yang sama

# %%
# dfCek = pd.concat([dfUSCategoryVid,dfUSCategoryJson])
# dfCek = pd.concat([dfUSCategoryVid,dfUSCategoryJson]).drop_duplicates() # menghapus duplikat dan menyisakan data non duplikat
dfCek = pd.concat([dfUSCategoryVid,dfUSCategoryJson]).drop_duplicates(keep=False) # menghapus duplikat beserta data non duplikatnya (menyisakan data yang tidak memiliki duplikat)

# %%
dfCek
# Out:
#     category_id          category
# 5            18      Short Movies
# 8            21     Videoblogging
# 17           30            Movies
# 18           31   Anime/Animation
# 19           32  Action/Adventure
# 20           33          Classics
# 21           34            Comedy
# 22           35       Documentary
# 23           36             Drama
# 24           37            Family
# 25           38           Foreign
# 26           39            Horror
# 27           40    Sci-Fi/Fantasy
# 28           41          Thriller
# 29           42            Shorts
# 31           44          Trailers

# %%
dfUSCategory = dfUSCategoryVid

# %% [markdown]
# ## 2. VISUALISASI DATA

# %% [markdown]
# ### Import Import Seaborn & Matplotlib
# Seaborn adalah versi modifikasi dari Matplotlib. Maka dari itu, Matplotlib tetap dibutuhkan dan harus di-import.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Library Bokeh

# %%
# import bokeh
from bokeh.plotting import figure, show, output_notebook, reset_output
from bokeh.models import ColumnDataSource, BasicTickFormatter
from bokeh.models.tools import HoverTool
from bokeh.layouts import Row
from bokeh.palettes import Category20

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dfUSVideos.isna(), yticklabels= False )

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# #### Scatter Plot Views / Likes

# %%
ax = plt.subplots(figsize=(15,10))
    
sns.scatterplot(x='views',y='likes', data = dfUSVideos)

# %% [markdown]
# #### Scatter Plot Likes/Dislikes

# %%
ax = plt.subplots(figsize=(15,10))

sns.scatterplot(x='likes',y='dislikes', data=dfUSVideos)

# %% [markdown]
# #### Scatter Plot Comment / Likes & Comment / Views

# %%
fig, axis = plt.subplots(1,2, figsize=(20,10))

sns.scatterplot(x='comment_count', y='likes', data=dfUSVideos, ax = axis[0])
sns.scatterplot(x='comment_count', y='views', data=dfUSVideos, ax = axis[1])

# %% [markdown]
# ## TOP-5 KATEGORI BERDASARKAN JUMLAH VIDEO YANG TRENDING
# Top-5 kategori berdasarkan video yang trending akan divisualisasikan menggunakan diagram batang dengan bantuan Seaborn

# %% [markdown]
# ### Pembuatan Dataframe Berisi Jumlah Video yang Trending Berdasarkan Kategori

# %% [markdown]
# Dictionary yang menampung :
# <b>
#  - ID Kategori ('id')
#  - Nama Kategori ('category')
#  - Jumlah Video Trending ('video_count')
# </b>

# %% [markdown]
# ### Mengelompokkan Data Berdasarkan kolom 'category_id' pada dataframe video
# Pengelompokkan dilakukan dengan <b>.groupby()</b>.

# %%
# US
gUSVideos = dfUSVideos.groupby('category_id')

# %%
gUSVideos.get_group(2).head(5)

# %%
data_count_category_us = {
    
    # id kategori diambil dari  kolom 'category_id'
    'category_id' : [items for items in dfUSCategory['category_id']],
    'category' : [items for items in dfUSCategory['category']],
    'video_count': [gUSVideos.get_group(items)['tags'].count() for items in dfUSCategory['category_id']]
    
}

# %%
# dimasukkan ke dalam dataframe
dfCatCountUS = pd.DataFrame(data_count_category_us)

print("JUMLAH VIDEO YANG TRENDING BERDASARKAN KATEGORI UNITED STATES")
dfCatCountUS

# %% [markdown]
# ### Membuat Dataframe TOP-5

# %%
# sorting tertinggi
dfTop5US = dfCatCountUS.nlargest(5, "video_count")

# reindex dari 1
dfTop5US.index = np.arange(1, len(dfTop5US) + 1)

# %%
print("TOP-5 KATEGORI DENGAN VIDEO TRENDING TERBANYAK DI UNITED STATES")
dfTop5US

# %% [markdown]
# ## Visualisasi Diagram Batang Top-5 dengan Seaborn

# %%
# pembuatan figure 1 aksis dengan besar 15x10 inci
fig = plt.figure(figsize=(15, 10))

# seting whitegrid agar background berwarna putih
sns.set(style="whitegrid", font_scale = 1.5)

# pembuatan plot dengan barplot
ax = sns.barplot(x = dfTop5US['video_count'], y =dfTop5US['category'])

# penamaan judul
plt.title("TOP-5 KATEGORI BERDASARKAN JUMLAH VIDEO YANG TRENDING DI UNITED STATES", fontsize=18)

# penamaan label horizontal dan vertikal
plt.xlabel("JUMLAH VIDEO", fontsize=14)
plt.ylabel("NAMA KATEGORI", fontsize=14)

# %% [markdown]
# ## RATA-RATA PENONTON DARI TIAP KATEGORI

# %%
# memasukkan data ke dalam list
data_view_us = {
    
    # id kategori
    'category_id' : [items for items in dfUSCategory['category_id']],

    #penonton rata-rata
    'average_views':[gUSVideos.get_group(items)['views'].mean() for items in dfUSCategory['category_id']]
}

dfViewUS = pd.DataFrame(data_view_us)

# %%
# penyatuan dataframe yang telah dibuat tadi dengan data kategori Canada agar nama kategori dapat ditampilkan.
dfViewUS = pd.merge(dfUSCategory,dfViewUS,on="category_id")

# %%
dfViewUS

# %% [markdown]
# ## Visualisasi Diagram Batang dengan Bokeh

# %%
# sort
dfViewUS_sortAvg = dfViewUS.sort_values(by="average_views",ascending=False)

# buat ColumnDataSource dari dataframe dfViewCA
source = ColumnDataSource(dfViewUS_sortAvg)

# %%
dfViewUS_sortAvg

# %%
# pembuatan object figure dan menentukan x range nya
bpUS = figure (
    x_range = (source.data['category'].tolist())
)

# setingan tinggi dan lebar figure berdasarkan piksel
bpUS.width = 1280
bpUS.height = 720

# plotting dengan vbar
bpUS.vbar(
    x='category', 
    top='average_views', 
    source=source, 
    width=0.7,
    fill_color="red"
)

# %%
# judul
bpUS.title.text ='VIEWER RATA-RATA BERDASARKAN KATEGORI UNITED STATES'
bpUS.title.align = 'center'
bpUS.title.text_font_size = '14pt'
bpUS.title.text_font = "times"

# pembuatan x-axis dan orientasinya
bpUS.xaxis.axis_label = 'Kategori'
bpUS.xaxis.major_label_orientation = 1
bpUS.xaxis.axis_label_text_font_size = "12pt"
bpUS.xaxis.major_label_text_font_size = "11pt"
bpUS.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
bpUS.yaxis.axis_label = 'Jumlah Viewer'
bpUS.yaxis.axis_label_text_font_size = "12pt"
bpUS.yaxis.major_label_text_font_size = "9pt"
bpUS.yaxis.axis_label_text_font = "times"
bpUS.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Rata-rata Viewer',  '@average_views{0.0,000}' )
  ]
)
bpUS.add_tools(hover)

# %% [markdown]
# ## RATA-RATA PENONTON DARI TIAP KATEGORI DI UNITED STATES

# %%
# output
output_notebook()
show(bpUS)

# %% [markdown]
# ## JUMLAH VIDEO TRENDING PER HARI BERDASARKAN KATEGORI

# %% [markdown]
# Dataframe video tidak memiliki nama kategori & hanya ada id kategori

# %%
dfUSVideos.head(2)

# %%
# menyatukan dataframe video dengan kategori berdasarkan id kategori agar mendapatkan nama kategori yang berasal dari dataframe kategori
dfUSVideos = pd.merge(dfUSCategory,dfUSVideos,on="category_id")

# %%
dfUSVideos.head(2)

# %%
# melakukan crosstab untuk menghitung frekuensi data berdasarkan index yang ditentukan, yang bertindak sebagai index di sini adalah kolom trending_date 
dfUSTrendPerDay = pd.crosstab([dfUSVideos.trending_date], [dfUSVideos.category])

# %%
dfUSTrendPerDay

# %% [markdown]
# ## Visualisasi Diagram Garis dengan Bokeh

# %%
# sumber data
source = ColumnDataSource(dfUSTrendPerDay)

# pemilihan palette warna
mypalette=Category20[17]
col=dfUSTrendPerDay.columns.tolist()


lpUS = figure(width=1600, height=720, x_axis_type="datetime") 
for (columnnames, colore) in zip(col, mypalette):
    lpUS.line(dfUSTrendPerDay.index, 
           dfUSTrendPerDay[columnnames], 
           legend = columnnames, 
           color = colore,
           line_width = 2,
           name = columnnames
          )

# %%
# judul 
lpUS.title.text ='JUMLAH VIDEO TRENDING PER HARI BERDASARKAN KATEGORI UNITED STATES'
lpUS.title.align = 'center'
lpUS.title.text_font_size = '18pt'
lpUS.title.text_font = "times"

# pembuatan x-axis dan orientasinya
lpUS.xaxis.axis_label = 'Tanggal'
lpUS.xaxis.major_label_orientation = 1
lpUS.xaxis.axis_label_text_font_size = "12pt"
lpUS.xaxis.major_label_text_font_size = "11pt"
lpUS.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
lpUS.yaxis.axis_label = 'Jumlah Video'
lpUS.yaxis.axis_label_text_font_size = "12pt"
lpUS.yaxis.major_label_text_font_size = "9pt"
lpUS.yaxis.axis_label_text_font = "times"

# pembuatan legend
lpUS.legend.background_fill_alpha = 0.0

# %%
# pembuatan hover tool
hover = HoverTool(
  tooltips=[
    ('Tanggal',  "@x{%Y-%m-%d}" ),
    ('Kategori',   '$name'),
    ('Jumlah Video', '@y{0}')
  ],
    formatters={
        '@x': 'datetime'
    }
)
lpUS.add_tools(hover)

# %% [markdown]
# ### JUMLAH VIDEO TRENDING PER HARI BERDASARKAN KATEGORI DI UNITED STATES

# %%
output_notebook()
show(lpUS)

# %% [markdown]
# ## TAG YANG PALING SERING DIGUNAKAN DI VIDEO TRENDING
# Akan ditelaah tag apa yang paling sering ditemukan dari data video yang mengalami trending dan divisualisasikan dengan library Word Cloud.

# %%
dfUSVideos.head(2)

# %%
dfUSVideos.tags

# %% [markdown]
# ### Install & Import Library Word Cloud

# %%
# Untuk Install Word Cloud
# conda install -c https://conda.anaconda.org/conda-forge wordcloud

# Import Word Cloud
from wordcloud import WordCloud

# %% [markdown]
# Kolom <b>'tags'</b> dijadikan list untuk kemudian dilakukan join dan dikonversi menjadi string. Kemudian dilakukan split & strip untuk mendapatkan tags yang diinginkan

# %%
# kolom tags tolist()
list_tags_us = dfUSVideos['tags'].tolist()

list_tags_us

# %% [markdown]
# list_tags_ca akan disatukan dengan fungsi join() agar menjadi string. String baru dengan nama string_tags_ca perlu dibuat terlebih dahulu dengan isi "|" agar "|" bertindak sebagai separator antar isi dari list setelah dilakukan join().

# %%
string_tags_us = "|"

# %%
string_tags_us = string_tags_us.join(list_tags_us)

# %% [markdown]
# Setelah dilakukan join, karakter " atau double quote perlu dihilangkan dengan fungsi replace()

# %%
string_tags_us = string_tags_us.replace('"', '')

# %% [markdown]
# String dikonversi menjadi lowercase untuk mempermudah penghitungan nantinya.

# %%
string_tags_us = string_tags_us.lower()

# %% [markdown]
# Kemudian fungsi split dilakukan terhadap karakter "|" untuk memisahkan antar teks dalam string tersebut dan menjadikannya array string.

# %%
string_tags_us = string_tags_us.split("|")

string_tags_us

# %%
# membuat kolom bernama tag yang berisikan array string string_tags_ca
dfUSVideos_tags = pd.DataFrame(string_tags_us, columns=['tag'])

# %%
#membuat dataframe baru dengan value_counts yang menghitung berapa kali tag muncul dalam datasets dfCAvdideos_tags
dfUSVideos_tags_count = pd.DataFrame(dfUSVideos_tags.tag.value_counts().reset_index())

#reset index dari 1
dfUSVideos_tags_count.index = dfUSVideos_tags_count.index + 1

#rename kolom
dfUSVideos_tags_count.columns = ['tag', 'tag_count']

# %%
print("TOP-5 TAG DI UNITED STATES")
dfUSVideos_tags_count.head(5)

# %% [markdown]
# ## Visualisasi Tag dengan Word Cloud

# %% [markdown]
# Untuk memvisualisasikan tag-tag yang paling sering muncul, digunakan <b>WordCloud</b>.
# WordCloud dapat membaca dictionary yang berisikan teksnya lalu frekuensinya.

# %% [markdown]
# Langkah pertama adalah mengkonversi dfCAvideos_tags_count menjadi dictionary. Dictionary terdiri dari data yang berasal dari kolom tag dan tag_count pada dataframe dfCAvideos_tags_count

# %%
# pembuatan dictionary yang berasal dari dataframe
dict_tags_US = dict(zip(dfUSVideos_tags_count['tag'].tolist(), dfUSVideos_tags_count['tag_count'].tolist()))

dict_tags_US

# %%
# membuat WordCloud dari dictionary penghitungan tag
wcUS = WordCloud(width=800, height=600, background_color ='white').generate_from_frequencies(dict_tags_US)

# %%
# seting plot & plotting
plt.figure(figsize=(20, 20))
plt.axis('off')
plt.title("TAG YANG DIGUNAKAN VIDEO DI UNITED STATES", fontsize=20)
plt.imshow(wcUS)
