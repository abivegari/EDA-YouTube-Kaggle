# %% [markdown]
# # EDA YOUTUBE DAILY TRENDING DATASETS GREAT BRITAIN

# %% [markdown]
# ## IMPORT LIBRARY YANG DIPERLUKAN

# %%
# import library
import pandas as pd
import json as js
from pandas.io.json import json_normalize

# import matplotlib
import matplotlib.pyplot as plt

# import numpy
import numpy as np

# import seaborn
import seaborn as sns
# %matplotlib inline

# import stats
from scipy import stats
import statistics

# ignore userwarning
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# import WordCloud
# conda install -c https://conda.anaconda.org/conda-forge wordcloud
from wordcloud import WordCloud

# %%
# import bokeh
from bokeh.plotting import figure, show, output_notebook, reset_output
from bokeh.models import ColumnDataSource, BasicTickFormatter
from bokeh.models.tools import HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Viridis11, Cividis11, Plasma11, Greys11

# %%
# load datasets GB
dfGBvideos = pd.read_csv("datasets/GBvideos.csv")
dfGBcategory = pd.read_csv("datasets/GBCategories.csv")

# set option agar float dapat ditampilkan seluruhnya
pd.set_option('float_format', '{:f}'.format)

# %% [markdown]
# ## IDENTIFIKASI ATRIBUT DATA VIDEO GREAT BRITAIN
# Berikut adalah atribut data video dari region Great Britain :

# %%
dfGBvideos.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %% [markdown]
# #### Karena kolom trending_date pada semua data video adalah string dengan format year.month.day (contoh : 17.11.14), maka objek dari kolom tersebut perlu diubah menjadi bentuk datetime

# %%
dfGBvideos['trending_date'] =  pd.to_datetime(dfGBvideos['trending_date'], format='%y.%d.%m')

# %%
dfGBvideos.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU    2017-11-14
# 1  3s1rvMFUweQ    2017-11-14
# 2  n1WpP7iowLc    2017-11-14
# 3  PUTEiSjKwJU    2017-11-14
# 4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
#                                                 tags     views   likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...   7224515   55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632   25561
# 2  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787420
# 3  Salford City FC|"Salford City"|"Salford"|"Clas...     27833     193
# 4                                             [none]      9815      30
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1      2294           2757  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
# 2     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 3        12             37  https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg
# 4         2             30  https://i.ytimg.com/vi/rHwDegptbI4/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...
# 1  Musical guest Taylor Swift performs …Ready for...
# 2  Eminem's new track Walk on Water ft. Beyoncé i...
# 3  Salford drew 4-4 against the Class of 92 and F...
# 4  Dashcam captures truck's near miss with child ...

# %%
dfGBvideos.shape
# Out:
# (38916, 16)

# %% [markdown]
# Berdasarkan pengecekan data video dari region Great Britain memiliki dimensi <b>40881 baris x 16 kolom</b>.

# %% [markdown]
# ## DATA KATEGORI VIDEO REGION GREAT BRITAIN
# Berikut adalah data kategori video region Great Britain setelah diubah menjadi dataframe :

# %%
dfGBcategory
# Out:
#     id               category
# 0    1       Film & Animation
# 1    2       Autos & Vehicles
# 2   10                  Music
# 3   15         Pets & Animals
# 4   17                 Sports
# 5   19        Travel & Events
# 6   20                 Gaming
# 7   22         People & Blogs
# 8   23                 Comedy
# 9   24          Entertainment
# 10  25        News & Politics
# 11  26          Howto & Style
# 12  27              Education
# 13  28   Science & Technology
# 14  29  Nonprofits & Activism
# 15  43                  Shows

# %%
dfGBcategory.shape
# Out:
# (16, 2)

# %% [markdown]
# Berdasarkan pengecekan data kategori region Great Britain memiliki dimensi <b>31 baris x 2 kolom</b>.

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## A. STATISTIK DARI SETIAP KATEGORI YANG TERDAPAT DI DATAFRAME VIDEOS GREAT BRITAIN
# Kita perlu mengetahui statistik berikut untuk setiap kategori :
# #### 1. Data tertinggi, terendah, dan rata-rata viewer
# #### 2. Data tertinggi, terendah, dan rata-rata likes
# #### 3. Data tertinggi, terendah, dan rata-rata dislikes
# #### 5. Data tertinggi, terendah, dan rata-rata jumlah komentar

# %% [markdown]
# Di sini kita akan menemukan statistik data video dari region Great Britain menggunakan list <b>gGBvideo</b> yang mana adalah list di mana video kelompokkan berdasarkan id kategori.<br/>
#
# Untuk menemukan rata-rata digunakan fungsi <b>.max()</b> pada data grup id kategori yang diinginkan. Untuk menemukan value tertinggi digunakan <b>.max()</b> dan untuk menemukan value terkecil digunakan <b>.min()</b>

# %%
# mengelompokan berdasarkan id kategori
gGBvideo = dfGBvideos.groupby('category_id')

# %% [markdown]
# ### 1A. Data tertinggi, terendah, dan rata-rata viewer Great Britain

# %%
# memasukkan data ke dalam list
data_view_gb = {
    
    # id kategori
    'id' : [items for items in dfGBcategory['id']],
    #penonton tertinggi
    'highest_views':[gGBvideo.get_group(items)['views'].max() for items in dfGBcategory['id']],
    
    #penonton terendah
    'lowest_views':[gGBvideo.get_group(items)['views'].min() for items in dfGBcategory['id']],
    
    #penonton rata-rata
    'average_views':[gGBvideo.get_group(items)['views'].mean() for items in dfGBcategory['id']],
    
    #median data
    'median_views':[gGBvideo.get_group(items)['views'].median() for items in dfGBcategory['id']
                   ]}

dfViewGB = pd.DataFrame(data_view_gb)

# %%
dfViewGB = pd.merge(dfGBcategory,dfViewGB,on="id")

print("")
print("DATA VIEWER SETIAP KATEGORI DI REGION GREAT BRITAIN")
dfViewGB
# Out:
# DATA VIEWER SETIAP KATEGORI DI REGION GREAT BRITAIN
#     id               category  highest_views  lowest_views   average_views  \
# 0    1       Film & Animation       42560014          2441  3245132.955374
# 1    2       Autos & Vehicles        5362914          1858  1487392.458333
# 2   10                  Music      424538912          2152 12444442.690781
# 3   15         Pets & Animals        6416920         25232  1013708.938202
# 4   17                 Sports       22975455          1930  1752352.487677
# 5   19        Travel & Events        6362355          3254  1383177.010417
# 6   20                 Gaming       18158133          7350   976856.561521
# 7   22         People & Blogs       62338362          1184  1966605.546480
# 8   23                 Comedy       43460605         10676  2167430.056346
# 9   24          Entertainment      169884583          2650  3264607.961530
# 10  25        News & Politics       18994966           851  1150311.326531
# 11  26          Howto & Style        8721841          1505   617300.428942
# 12  27              Education       11240174          8851   972189.402626
# 13  28   Science & Technology       21530325         38353  3168703.196911
# 14  29  Nonprofits & Activism       26703269         19270  3919980.688889
# 15  43                  Shows        1709880        876996  1429164.150000
#
#      median_views
# 0  1144917.000000
# 1  1044150.000000
# 2  2980744.000000
# 3   565055.000000
# 4   346392.000000
# 5   218176.000000
# 6   309154.500000
# 7   321208.000000
# 8  1278302.500000
# 9   786954.000000
# 10  229753.000000
# 11  263412.000000
# 12  402504.000000
# 13  715286.000000
# 14  672604.000000
# 15 1498767.500000

# %%
# sort
dfViewGB_sortHighest = dfViewGB.sort_values(by="highest_views",ascending=False)

# buat ColumnDataSource dari dataframe
source = ColumnDataSource(dfViewGB_sortHighest)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='highest_views', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Viridis11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='VIEWER TERTINGGI BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Viewer'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Jumlah Viewer',  '@highest_views' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1047">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8a67d775-6100-4ea2-9112-bf0f97d5ec1e" data-root-id="1002"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfViewGB_sortHighest['highest_views'], labels=dfViewGB_sortHighest['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("VIEWER TERTINGGI BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfViewGB_sortLowest = dfViewGB.sort_values(by="lowest_views",ascending=False)

# buat ColumnDataSource dari dataframe
source = ColumnDataSource(dfViewGB_sortLowest)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='lowest_views', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Cividis11,
        factors=source.data['category'].tolist()
    )
)

# judul 
p.title.text ='VIEWER TERENDAH BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Viewer'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Jumlah Viewer',  '@lowest_views' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1150">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e5fd4857-4295-4843-93b9-2469a120a626" data-root-id="1105"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfViewGB_sortLowest['lowest_views'], labels=dfViewGB_sortLowest['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("VIEWER TERENDAH BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfViewGB_sortAvg = dfViewGB.sort_values(by="average_views",ascending=False)

# buat ColumnDataSource dari dataframe dfViewGB
source = ColumnDataSource(dfViewGB_sortAvg)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='average_views', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Plasma11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='VIEWER RATA-RATA BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Viewer'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Rata-rata Viewer',  '@average_views' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1253">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0c74d8f1-4fc8-42ec-9b2c-9e471ba56435" data-root-id="1208"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfViewGB_sortAvg['average_views'], labels=dfViewGB_sortAvg['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("RATA-RATA VIEWER BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfViewGB_sortMedian = dfViewGB.sort_values(by="median_views",ascending=False)

# buat ColumnDataSource dari dataframe dfViewGB
source = ColumnDataSource(dfViewGB_sortMedian)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='median_views', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Greys11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='MEDIAN VIEWER BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Viewer'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Median Viewer',  '@median_views' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1356">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aecbc0ed-3a80-4f0e-a9f2-850bc4943204" data-root-id="1311"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfViewGB_sortMedian['median_views'], labels=dfViewGB_sortMedian['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("MEDIAN VIEWER BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %% [markdown]
# ### 2A. Data tertinggi, terendah, dan rata-rata likes Great Britain

# %%
# memasukkan data ke dalam list
data_likes_gb = {
    
    'id' : [items for items in dfGBcategory['id']],
    'highest_likes':[gGBvideo.get_group(items)['likes'].max() for items in dfGBcategory['id']],
    'lowest_likes':[gGBvideo.get_group(items)['likes'].min() for items in dfGBcategory['id']],
    'average_likes':[gGBvideo.get_group(items)['likes'].mean() for items in dfGBcategory['id']],
    'median_likes':[gGBvideo.get_group(items)['likes'].median() for items in dfGBcategory['id']
                   ]}

dfLikesGB = pd.DataFrame(data_likes_gb)

# %%
dfLikesGB = pd.merge(dfGBcategory,dfLikesGB,on="id")

print("")
print("DATA LIKES SETIAP KATEGORI DI REGION GREAT BRITAIN")
dfLikesGB
# Out:
# DATA LIKES SETIAP KATEGORI DI REGION GREAT BRITAIN
#     id               category  highest_likes  lowest_likes  average_likes  \
# 0    1       Film & Animation         461135             0   57205.523089
# 1    2       Autos & Vehicles         114841            61   24608.506944
# 2   10                  Music        5613827             0  272138.508943
# 3   15         Pets & Animals         187524           147   28629.913858
# 4   17                 Sports        1291139             0   39270.313057
# 5   19        Travel & Events          23791            54    9674.447917
# 6   20                 Gaming        1031695             0   39220.127517
# 7   22         People & Blogs         625174             0   46273.495899
# 8   23                 Comedy        1253154            22   78431.168490
# 9   24          Entertainment        3312868             0   81572.362012
# 10  25        News & Politics         610526            12   25021.685714
# 11  26          Howto & Style         341145             5   26639.183091
# 12  27              Education         383049            94   38440.687090
# 13  28   Science & Technology         392249             0   61531.127413
# 14  29  Nonprofits & Activism        2061275           708  271695.733333
# 15  43                  Shows          44588         34615   41836.900000
#
#     median_likes
# 0   16506.000000
# 1   10406.000000
# 2  104729.000000
# 3   13702.500000
# 4    4795.000000
# 5    9543.500000
# 6    8553.500000
# 7    8650.000000
# 8   24086.500000
# 9   19089.500000
# 10   3739.000000
# 11   8664.500000
# 12  12744.000000
# 13  19421.000000
# 14  18673.500000
# 15  42758.500000

# %%
# sort
dfLikesGB_sortHighest = dfLikesGB.sort_values(by="highest_likes",ascending=False)

# buat ColumnDataSource dari dataframe
source = ColumnDataSource(dfLikesGB_sortHighest)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='highest_likes', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Viridis11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='LIKES TERTINGGI BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Likes'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Jumlah Likes',  '@highest_likes' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1459">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d92a71f0-42db-4c6c-82db-e970c19ab089" data-root-id="1414"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfLikesGB['highest_likes'], labels=dfLikesGB['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("LIKES TERTINGGI BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfLikesGB_sortLowest = dfLikesGB.sort_values(by="lowest_likes",ascending=False)

# buat ColumnDataSource dari dataframe
source = ColumnDataSource(dfLikesGB_sortLowest)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='lowest_likes', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Cividis11,
        factors=source.data['category'].tolist()
    )
)

# judul 
p.title.text ='LIKES TERENDAH BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Likes'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Jumlah Likes',  '@lowest_likes' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1562">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ac3d772c-e209-48f2-8c1d-16856bff02fe" data-root-id="1517"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfLikesGB_sortLowest['lowest_likes'], labels=dfLikesGB_sortLowest['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("LIKES TERENDAH BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfLikesGB_sortAvg = dfLikesGB.sort_values(by="average_likes",ascending=False)

# buat ColumnDataSource dari dataframe dfLikesGB
source = ColumnDataSource(dfLikesGB_sortAvg)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='average_likes', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Plasma11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='LIKES RATA-RATA BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Likes'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Rata-rata Viewer',  '@average_likes' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1665">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bb8d3594-3042-4fc9-8015-9ce19a81a335" data-root-id="1620"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfLikesGB_sortAvg['average_likes'], labels=dfLikesGB_sortAvg['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("RATA-RATA LIKES BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfLikesGB_sortMedian = dfLikesGB.sort_values(by="median_likes",ascending=False)

# buat ColumnDataSource dari dataframe dfLikesGB
source = ColumnDataSource(dfLikesGB_sortMedian)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='median_likes', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Greys11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='MEDIAN LIKES BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Likes'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Median Viewer',  '@median_likes' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1768">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7fc815f5-eba5-44e3-a166-e5f326797182" data-root-id="1723"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfLikesGB_sortMedian['median_likes'], labels=dfLikesGB_sortMedian['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("MEDIAN LIKES BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %% [markdown]
# ### 3B. Data tertinggi, terendah, dan rata-rata dislikes Great Britain

# %%
# memasukkan data ke dalam list
data_dislikes_gb = {
    
    'id' : [items for items in dfGBcategory['id']],
    'highest_dislikes':[gGBvideo.get_group(items)['dislikes'].max() for items in dfGBcategory['id']],
    'lowest_dislikes':[gGBvideo.get_group(items)['dislikes'].min() for items in dfGBcategory['id']],
    'average_dislikes':[gGBvideo.get_group(items)['dislikes'].mean() for items in dfGBcategory['id']],
    'median_dislikes':[gGBvideo.get_group(items)['dislikes'].median() for items in dfGBcategory['id']
                   ]}

dfDislikesGB = pd.DataFrame(data_dislikes_gb)

# %%
dfDislikesGB = pd.merge(dfGBcategory,dfDislikesGB,on="id")

print("")
print("DATA DISLIKES SETIAP KATEGORI DI REGION GREAT BRITAIN")
dfDislikesGB
# Out:
# DATA DISLIKES SETIAP KATEGORI DI REGION GREAT BRITAIN
#     id               category  highest_dislikes  lowest_dislikes  \
# 0    1       Film & Animation             37132                0
# 1    2       Autos & Vehicles             12647                1
# 2   10                  Music            421473                0
# 3   15         Pets & Animals              3461                1
# 4   17                 Sports            193053                0
# 5   19        Travel & Events              2434                0
# 6   20                 Gaming             17093                0
# 7   22         People & Blogs            258504                0
# 8   23                 Comedy             38693                2
# 9   24          Entertainment           1944971                0
# 10  25        News & Politics             37789                0
# 11  26          Howto & Style             13141                3
# 12  27              Education              8924                4
# 13  28   Science & Technology             19405                0
# 14  29  Nonprofits & Activism            545595                5
# 15  43                  Shows               361              234
#
#     average_dislikes  median_dislikes
# 0        2403.156383       798.000000
# 1        1952.708333      1012.000000
# 2       11587.191799      2159.000000
# 3         685.505618       289.000000
# 4        5199.032512       180.000000
# 5         361.614583       115.000000
# 6        1288.846756       336.000000
# 7        4102.040328       266.000000
# 8        2533.107768       896.500000
# 9        9656.526852       656.000000
# 10       3085.999184       560.000000
# 11        833.606328       248.000000
# 12       1297.927790       401.000000
# 13       3133.299228       754.000000
# 14      60409.488889       876.500000
# 15        319.800000       329.500000

# %% [markdown]
# ### 4B. Data tertinggi, terendah, dan rata-rata jumlah komentar Great Britain

# %%
# memasukkan data ke dalam list
data_comments_gb = {

    'id' : [items for items in dfGBcategory['id']],
    'highest_comments':[gGBvideo.get_group(items)['comment_count'].max() for items in dfGBcategory['id']],
    'lowest_comments':[gGBvideo.get_group(items)['comment_count'].min() for items in dfGBcategory['id']],
    'average_comments':[gGBvideo.get_group(items)['comment_count'].mean() for items in dfGBcategory['id']],
    'median_comments':[gGBvideo.get_group(items)['comment_count'].median() for items in dfGBcategory['id']
                   ]}

dfCommentsGB = pd.DataFrame(data_comments_gb)

# %%
dfCommentsGB = pd.merge(dfGBcategory,dfCommentsGB,on="id")

print("")
print("DATA COMMENTS SETIAP KATEGORI DI REGION GREAT BRITAIN")
dfCommentsGB
# Out:
# DATA COMMENTS SETIAP KATEGORI DI REGION GREAT BRITAIN
#     id               category  highest_comments  lowest_comments  \
# 0    1       Film & Animation             50255                0
# 1    2       Autos & Vehicles             12083                0
# 2   10                  Music           1228655                0
# 3   15         Pets & Animals             18532               23
# 4   17                 Sports             91663                0
# 5   19        Travel & Events              2716                7
# 6   20                 Gaming             31803                0
# 7   22         People & Blogs            154958                0
# 8   23                 Comedy            205692                4
# 9   24          Entertainment           1626501                0
# 10  25        News & Politics             86221                0
# 11  26          Howto & Style            139582                9
# 12  27              Education             19451                0
# 13  28   Science & Technology             53786                0
# 14  29  Nonprofits & Activism            704824               95
# 15  43                  Shows              4335             3448
#
#     average_comments  median_comments
# 0        6049.674428      2212.000000
# 1        3507.534722      2647.500000
# 2       21303.849062      5782.500000
# 3        2630.520599      1212.500000
# 4        5273.322496       677.000000
# 5        1231.010417      1207.500000
# 6        3449.101790      1219.500000
# 7        6395.471292      1030.000000
# 8        9145.960613      2328.500000
# 9       12812.082420      1961.000000
# 10       7662.533878      1601.000000
# 11       3815.506224       637.000000
# 12       3581.844639      1628.000000
# 13       7778.117761      2092.500000
# 14      85253.222222      2321.500000
# 15       4047.850000      4118.000000

# %%
# sort
dfCommentsGB_sortHighest = dfCommentsGB.sort_values(by="highest_comments",ascending=False)

# buat ColumnDataSource dari dataframe
source = ColumnDataSource(dfCommentsGB_sortHighest)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='highest_comments', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Viridis11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='JUMLAH KOMENTAR TERTINGGI BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Komentar'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Jumlah Komentar',  '@highest_comments' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1871">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7da568f4-e0f3-426f-9a3c-3bd916efdb10" data-root-id="1826"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfCommentsGB_sortHighest['highest_comments'], labels=dfCommentsGB_sortHighest['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("JUMLAH KOMENTAR TERTINGGI BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfCommentsGB_sortLowest = dfCommentsGB.sort_values(by="lowest_comments",ascending=False)

# buat ColumnDataSource dari dataframe
source = ColumnDataSource(dfCommentsGB_sortLowest)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='lowest_comments', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Cividis11,
        factors=source.data['category'].tolist()
    )
)

# judul 
p.title.text ='JUMLAH KOMENTAR TERENDAH BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Komentar'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Jumlah Komentar',  '@lowest_comments' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1974">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ac75de1a-d930-4e77-8e02-c29b4aa16040" data-root-id="1929"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

explode = (0.1, 0, 0, 0, 0, 0)  

ax1.pie(dfCommentsGB_sortLowest['lowest_comments'], labels=dfCommentsGB_sortLowest['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("JUMLAH KOMENTAR TERENDAH BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfCommentsGB_sortAvg = dfCommentsGB.sort_values(by="average_comments",ascending=False)

# buat ColumnDataSource dari dataframe dfCommentsGB
source = ColumnDataSource(dfCommentsGB_sortAvg)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='average_comments', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Plasma11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='JUMLAH KOMENTAR RATA-RATA BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Komentar'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Rata-rata Komentar',  '@average_comments' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2077">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="47e0b698-61e4-48f8-aec7-a357d705a5f6" data-root-id="2032"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfCommentsGB_sortAvg['average_comments'], labels=dfCommentsGB_sortAvg['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("JUMLAH KOMENTAR RATA-RATA BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %%
# sort
dfCommentsGB_sortMedian = dfCommentsGB.sort_values(by="median_comments",ascending=False)

# buat ColumnDataSource dari dataframe dfCommentsGB
source = ColumnDataSource(dfCommentsGB_sortMedian)

# pembuatan Figure
p = figure (
    x_range = source.data['category'].tolist()
)

# plotting dengan vbar
p.vbar(
    x='category', 
    top='median_comments', 
    source=source, 
    width=0.7,
    fill_color=factor_cmap(
        'category',
        palette=Greys11,
        factors=source.data['category'].tolist()
    )
)

# judul
p.title.text ='MEDIAN KOMENTAR BERDASARKAN KATEGORI GREAT BRITAIN'
p.title.align = 'center'
p.title.text_font_size = '14pt'
p.title.text_font = "times"

# pembuatan x-axis dan orientasinya
p.xaxis.axis_label = 'Kategori'
p.xaxis.major_label_orientation = 1
p.xaxis.axis_label_text_font_size = "12pt"
p.xaxis.major_label_text_font_size = "11pt"
p.xaxis.axis_label_text_font = "times"

# pembuatan y-axis
p.yaxis.axis_label = 'Jumlah Komentar'
p.yaxis.axis_label_text_font_size = "12pt"
p.yaxis.major_label_text_font_size = "9pt"
p.yaxis.axis_label_text_font = "times"
p.yaxis.formatter = BasicTickFormatter(use_scientific=False)

# setingan tinggi dan lebar figure
p.width = 900
p.height = 700

# seting hover
hover = HoverTool(
  tooltips=[
    ('Kategori',   '@category'),
    ('Median Komentar',  '@median_comments' )
  ]
)
p.add_tools(hover)

# output
output_notebook()
show(p)
reset_output()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2180">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b97693a6-2068-4b12-bf57-f68f7d8905ba" data-root-id="2135"></div>

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))

ax1.pie(dfCommentsGB_sortMedian['median_comments'], labels=dfCommentsGB_sortMedian['category'], autopct='%1.1f%%', textprops={'fontsize': 12})
ax1.axis('equal') 

# legend
ax1.legend(loc="topright")

plt.title("JUMLAH KOMENTAR MEDIAN BERDASARKAN KATEGORI GREAT BRITAIN", bbox={'facecolor':'0.8', 'pad':5}, fontsize="18")

plt.show()

# %% [markdown]
# ### 5B. Melihat pengaruh tag terhadap kategori dengan viewer rata-rata tertinggi

# %% [markdown]
# Setelah ditelusuri pada negara Great Britain viewer rata-rata tertinggi adalah kategori 'Music'. Di sini akan ditelaah tag apa yang paling sering digunakan oleh pengunggah video dan divisualisasikan dengan Word Cloud. Kemudian akan dilaah dampaknya terhadap jumlah viewer

# %%
# membuat dataframe baru berisi video-video dengan kategori 'Music' dengan category_id 10
dfGBmusic = dfGBvideos[dfGBvideos['category_id'] == 10]

# %%
dfGBmusic
# Out:
#           video_id trending_date  \
# 2      n1WpP7iowLc    2017-11-14
# 6      2Vv-BfVoq4g    2017-11-14
# 8      LMCuKltaY3M    2017-11-14
# 9      9t9u_yPEidY    2017-11-14
# 12     NVCqz2BDfcQ    2017-11-14
# ...            ...           ...
# 38910  uKxWP56VStM    2018-06-14
# 38911  l884wKofd54    2018-06-14
# 38912  IP8k2xkhOdI    2018-06-14
# 38913  Il-an3K9pjg    2018-06-14
# 38915  4YFo4bdMO8Q    2018-06-14
#
#                                                    title        channel_title  \
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé           EminemVEVO
# 6            Ed Sheeran - Perfect (Official Music Video)           Ed Sheeran
# 8       Elbow - Golden Slumbers (John Lewis Advert 2017)            ElbowVEVO
# 9      Jennifer Lopez - Amor, Amor, Amor (Official Vi...    JenniferLopezVEVO
# 12                  Gucci Mane  - Curve (ft. The Weeknd)    OfficialGucciMane
# ...                                                  ...                  ...
# 38910         Jeremy Zucker - all the kids are depressed     JeremyZuckerVEVO
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...  EnriqueIglesiasVEVO
# 38912  Jacob Sartorius - Up With It (Official Music V...      Jacob Sartorius
# 38913                 Anne-Marie - 2002 [Official Video]           Anne-Marie
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...       SuperDuperKyle
#
#        category_id              publish_time  \
# 2               10  2017-11-10T17:00:03.000Z
# 6               10  2017-11-09T11:04:14.000Z
# 8               10  2017-11-10T08:00:01.000Z
# 9               10  2017-11-10T15:00:00.000Z
# 12              10  2017-11-10T17:18:13.000Z
# ...            ...                       ...
# 38910           10  2018-05-10T16:00:09.000Z
# 38911           10  2018-05-09T07:00:01.000Z
# 38912           10  2018-05-11T17:09:16.000Z
# 38913           10  2018-05-08T11:05:08.000Z
# 38915           10  2018-05-11T04:06:35.000Z
#
#                                                     tags     views    likes  \
# 2      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787420
# 6      edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634124
# 8      Elbow|"Golden"|"Slumbers"|"Polydor"|"Alternative"    154494     2163
# 9      Jennifer Lopez ft. Wisin|"Jennifer Lopez ft. W...   9548677   190084
# 12     Gucci Mane|"The Weeknd"|"Curve"|"Official"|"Mu...    946859    37986
# ...                                                  ...       ...      ...
# 38910  Jeremy|"Zucker"|"all"|"the"|"kids"|"are"|"depr...   1939400   169578
# 38911  Enrique Iglesias feat. Pitbull|"MOVE TO MIAMI"...  25066952   268088
# 38912  jacob sartorius|"jacob"|"up with it"|"jacob sa...   1492219    61998
# 38913  anne|"marie"|"anne-marie"|"2002"|"two thousand...  29641412   394830
# 38915  Kyle|"SuperDuperKyle"|"Ikuyo"|"2 Chainz"|"Soph...    607552    18271
#
#        dislikes  comment_count  \
# 2         43420         125882
# 6         21082          85067
# 8           147            211
# 9         15015          11473
# 12          816           2006
# ...         ...            ...
# 38910      1202           5889
# 38911     12783           9933
# 38912     13781          24330
# 38913      8892          19988
# 38915       274           1423
#
#                                        thumbnail_link  comments_disabled  \
# 2      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 6      https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg              False
# 8      https://i.ytimg.com/vi/LMCuKltaY3M/default.jpg              False
# 9      https://i.ytimg.com/vi/9t9u_yPEidY/default.jpg              False
# 12     https://i.ytimg.com/vi/NVCqz2BDfcQ/default.jpg              False
# ...                                               ...                ...
# 38910  https://i.ytimg.com/vi/uKxWP56VStM/default.jpg              False
# 38911  https://i.ytimg.com/vi/l884wKofd54/default.jpg              False
# 38912  https://i.ytimg.com/vi/IP8k2xkhOdI/default.jpg              False
# 38913  https://i.ytimg.com/vi/Il-an3K9pjg/default.jpg              False
# 38915  https://i.ytimg.com/vi/4YFo4bdMO8Q/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 2                 False                   False
# 6                 False                   False
# 8                 False                   False
# 9                 False                   False
# 12                False                   False
# ...                 ...                     ...
# 38910             False                   False
# 38911             False                   False
# 38912             False                   False
# 38913             False                   False
# 38915             False                   False
#
#                                              description
# 2      Eminem's new track Walk on Water ft. Beyoncé i...
# 6      🎧: https://ad.gt/yt-perfect\n💰: https://atlant...
# 8      “Golden Slumbers”, originally by The Beatles, ...
# 9      Jennifer Lopez ft. Wisin - Amor, Amor, Amor (O...
# 12     Gucci Mane - Curve feat. The Weeknd\n\n Mr. Da...
# ...                                                  ...
# 38910  For people watching this video, I hope that th...
# 38911  NEW SONG - MOVE TO MIAMI feat. Pitbull (Click ...
# 38912  THE OFFICIAL UP WITH IT MUSIC VIDEO!Get my new...
# 38913  Get 2002 by Anne-Marie HERE ▶ http://ad.gt/200...
# 38915  Debut album 'Light of Mine' out now: http://ky...
#
# [13754 rows x 16 columns]

# %% [markdown]
# Kolom tags akan dijadikan list untuk kemudian dilakukan join dan dikonversi menjadi string. Kemudian dilakukan split & strip untuk mendapatkan tags yang diinginkan

# %%
# kolom tags tolist()
list_tags_gb = dfGBmusic['tags'].tolist()

list_tags_gb
# Out:
# ['Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady
#  'Arvo|"Pärt"|"Tabula"|"Rasa"|"part"|"violin"|"concerto"|"violino"|"Arvo Pärt (Musical Artist)"|"sinduonitria"|"música"|"clássica"|"classica"|"musica"|"classical"|"music"|"minimalism"|"minimalismo"',
#  'Post Malone|"Post Malone rockstar"|"rockstar"|"21 Savage"|"Stoney"|"Beerbongs & Bentleys"|"Beerbongs"|"Bentleys"|"Austin post"|"rockstar post malone"|"post malone rockstar ft 21 savage"|"post malone - rockstar"|"21 savage post malone"|"post malone 21 savage"|"post malone ft 21 savage"|"Beerbongs and Bentleys"',
#  'newmusic|"indie"|"bbc6music"|"alternative"|"Field Music"|"Open Here"',
#  'Ozuna|"Reggaeton"|"Odisea"|"Odisea The Album"|"Música Sin Fronteras"|"Documentary"|"YouTube Documentary"|"Documental"|"Musica Sin Fronteras"',
#  'Taylor Swift|"Call It What You Want"|"reputation"',
#  'Migos|"Cardi B"|"Cardi"|"Nicki Minaj"|"Nicki"|"Minaj"|"Motorsport"|"Motor"|"Sport"|"Motor Sport"|"Culture 2"',
#  'hot97|"hot97app"|"music"|"video"|"hip hop"|"rap"|"r&b"|"hip-hop"|"New York"|"NY"|"US"|"United States"|"HOT97.com"',
#  'ZHU|"Exhale/Stardust"|"(Music"|"Video)"|"Mind"|"of"|"Genius"|"Club/Dance"|"Electronic"',
#  'Hip Hop|"Lemon"|"N.E.R.D & Rihanna"|"i am OTHER/Columbia"',
#  'ByStorm Entertainment/RCA Records|"Miguel"|"R&B"|"Told You So"',
#  'vance joy|"like gold"|"official audio"|"nation of two"',
#  'Maroon|"A-Trak"|"What"|"Lovers"|"Do"|"222"|"Records/Interscope"|"Records"|"Pop"',
#  'Chris|"Stapleton"|"Scarecrow"|"In"|"The"|"Garden"|"Mercury"|"Nashville"|"Country"',
#  'Selena|"Gomez"|"Marshmello"|"Wolves"|"Interscope"|"Records"|"Pop"',
#  'Madison|"Beer"|"Say"|"It"|"To"|"My"|"Face"|"(Official"|"Audio)"|"Ditto"|"Music"|"Pop"',
#  'Don Diablo|"electronic music"|"electronic"|"ARIZONA"|"Take Her Place"|"Future"|"EDM"|"House"|"Pop"|"Cutting Shapes"|"Chill"|"On My Mind"|"Chemicals"|"Lyric Video"|"Dont let go"|"don diably lyrics"|"arizona lyric video"|"wolves lyric video"|"New Don Diablo"|"Don Diablo ID"|"Don Diablo AMF"|"ADE 2017"|"Don Diablo ADE"|"the spectre"|"silence"|"hello there"|"crowd control"|"to the left left left"|"you can take her place tonight"',
#  'Luke|"Bryan"|"Most"|"People"|"Are"|"Good"|"Capitol"|"Records"|"Nashville"|"Country"',
#  'music|"official"|"music video"|"Bright"|"Bright: The Album"|"Bright The Album"|"Bastille"|"World Gone Mad"|"Atlantic Records"|"will smith"|"orc"|"Indie"|"alternative"|"soundtrack"',
#  'Empire|"Of"|"The"|"Sun"|"Way"|"To"|"Go"|"EMI"|"Alternative"|"eots"|"waay"|"too"|"goo"|"emipre of the sun"|"son"|"electronic"|"edm"|"australian"|"adm"|"aussie music. triplej"|"like a version"|"two leaves"|"flume"|"alison wonderland"|"cut copy"|"pnau"|"mgmt"|"hot chip"|"the presets"|"phoenix"|"hermitude"|"Nobumichi Asai"|"Ryo Kitabatake"',
#  'Sia Snowman Holiday',
#  'Niall Horan|"Niall"|"Horan"|"Too Much To Ask"|"Too Much Too Ask"|"To Much To Ask"|"To Much Too Ask"|"TMTA"|"Too Much To Ask Acoustic"|"Too Much Too Ask Acoustic"|"To Much To Ask Acoustic"|"To Much Too Ask Acoustic"|"TMTA Acoustic"|"Acoustic"|"Acoustic Video"',
#  'Sigrid|"Strangers"|"Island"|"Records"|"Pop"',
#  'the script|"the script new single"|"the script arms open"|"the script arms open acoustic"|"the script arms open acoustic version"|"rain"|"hall of fame"|"breakeven"|"superheroes"|"rain lyrics"|"for the first time"|"the man who can\'t be moved"|"if you could see me now"|"Arms Open (Acoustic)"|"Columbia"|"Pop"|"The Script"',
#  'power 106 hip hop interviews performance rap los angeles celebrity news|"Hip Hop"|"Hip-Hop"|"West Coast"|"Rap"|"Music"',
#  'Thirty|"Seconds"|"To"|"Mars"|"Walk"|"On"|"Water"|"to"|"Mars/Interscope"|"Records"|"Alternative"|"Thirty Seconds To Mars"|"Thirty Seconds to Mars Ellen"|"30 seconds to mars ellen"|"mars ellen"|"ellen"|"Walk On Water"|"Thirty Seconds to Mars"|"30 seconds to mars walk on water"|"thirty seconds to mars walk on water"|"mars"|"mars walk on water"|"walk on water vid"|"30 sec to mars"|"30 secs to mars walk on water"|"walk on water video"|"official video"|"vid"',
#  'Columbia|"Harry Styles"|"Kiwi"|"Pop"',
#  'earmusic|"live 2017"|"new album"|"music video"|"download"|"thunder"|"christmas day"|"rip it up"|"christmas"|"christmas song"|"danny bowes"',
#  'virtual|"self"|"neotrance"|"house"|"trance"|"electronic"|"electro"|"porter robinson"|"virtual self"|"virtualself"|"electronic music"|"ghost"|"voices"|"ghost voices"|"ghostvoices"|"pathselector"|"technic"|"angel"|"technic_angel"|"technicangel"|"porter"|"robinson"|"electronicmusic"|"visualizer"|"lyric video"|"official audio"|"audio"|"2017"|"new porter robinson"|"porter robinson 2017"',
#  'trap city|"trapcity"|"trap"|"city"|"trap music"|"future bass"|"edm"|"electronic music"|"electronic dance music"|"Alison Wonderland - Happy Place"|"alison wonderland"|"happy place"|"alison wonderland happy place"|"happy place alison wonderland"',
#  'lorde|"bruce springsteen"|"I\'m on fire"|"Christchurch"|"Isaac Theatre Royal"|"springsteen"|"nz"|"New Zealand"|"Theatre Royal"|"Ella Yelich-O\'Connor"|"Ray Suen"|"lordemusic"|"cover"|"400 Lux"|"Melodrama World Tour"|"Melodrama"|"Lorde"|"Ella"|"born in the USA"|"E Street Band"',
#  'Lady|"Gaga"|"The"|"Cure"|"AMAs"|"American"|"Music"|"Awards"|"Joanne"|"World"|"Tour"|"will"|"be"|"right"|"by"|"your"|"side"|"I’ll"|"fix"|"you"|"with"|"my"|"love"',
#  'Linkin Park',
#  'Domino|"Domino Records"|"Domino Recording Co"|"Richard dawson"|"Richard dawson live"|"peasant"|"peasant full album"|"ogre"|"the vile stuff"|"soldier"|"kissing compilation"|"ghost of a tree"|"wooden bag"|"nothing important"|"live session"|"weaver"|"shapeshifter"|"scientist"|"herald"|"prostitute"|"the magic bridge"|"full album"|"the glass trunk"|"richard dawson ogre live"|"richard dawson ogre lyrics"|"richard dawson soldier live"|"richard dawson soldier lyrics"|"weird world"',
#  'SZA|"LIFT SZA"|"Vevo SZA"|"Go Gina"|"SZA Go Gina"|"SZA Ctrl"|"Ctrl"|"R&B"|"SZA R&B"|"SZA live"|"SZA videos"|"SZA music videos"|"music videos"|"vevo videos"|"streaming video"|"streaming music"',
#  '[none]',
#  'portugal the man|"portugal. the man"|"woodstock"|"feel it still"|"american music awards"|"ama"|"john gourley"|"feel it still band"',
#  'Kpop|"1theK"|"원더케이"|"loen"|"로엔"|"뮤비"|"티져"|"MV"|"Teaser"|"신곡"|"new"|"song"|"한류"|"hallyu"|"ロエン"|"ミュージック"|"ミュージックビデオ"|"ケーポップ"|"韓国の歌"|"アイドル"|"韓流"|"韓国"|"아이돌"|"idol"|"KARD"|"You In Me"|"비엠"|"제이셉"|"전소민"|"전지우"|"BM"|"Jseph"|"somin"|"Jiwoo"',
#  'green day|"green"|"day"|"official"|"music"|"music video"',
#  'Nate|"Wiegman"|"lil peep"|"gustav ahr"|"downtown"|"lederrick"|"wiggy"|"mezzy"',
#  'BPG/RVG/RCA Records|"G-Eazy & Halsey"|"Him & I"|"Rap"',
#  'edsheeran|"ed sheeran"|"acoustic"|"live"|"cover"|"official"|"remix"|"official video"|"lyrics"|"session"|"beyonce"|"beyonce live"',
#  'wtf is going on',
#  'new snapchat|"version 2"|"snap inc"|"brandnew"|"update"|"software"|"snap"|"new update"|"redesign"|"reorganize"|"Snapchat"',
#  'taylor swift|"reputation"|"acoustic"|"live"|"soul"|"pop"|"music"|"viola"|"violin"|"cello"|"broadway"|"wicked"|"the color purple"|"cover"',
#  'Martin Garrix|"EDM"|"Animals"|"Wizard"|"Proxy"|"BFAM"|"Tremor"|"GRX"|"Ultra"|"EDC"|"Dance music"|"Martin"|"Garrix"|"House"|"Techno"|"Hardwell"|"Tiesto"|"Skrillex"|"Avicii"|"Virus"|"Beatport"|"DJ Mag"|"David Guetta"|"in the name of love"|"jamie scott"|"romy dya"|"so far away"',
#  'Sia Candy Cane Lane Holiday',
#  'Sigrid|"Strangers"|"Island"|"Records"|"Pop"',
#  'Sam|"Smith"|"One"|"Last"|"Song"|"Capitol"|"Pop"',
#  'billboard|"billboard channel"|"official"|"billboard magazine"|"music"|"official billboard channel"|"kelly clarkson"|"kelly clarkson speech"|"acceptance speech"|"kelly"|"clarkson"|"powerhouse"|"women in music"|"women"|"in"|"wim"|"wim 2017"|"women in music 2017"|"billboard women in music"|"singer"|"feminism"|"pop"|"pop music"|"kelly clarkson women in music"|"songwriter"|"2017"',
#  'SZA|"LIFT SZA"|"Vevo SZA"|"Go Gina"|"SZA Go Gina"|"SZA Ctrl"|"Ctrl"|"R&B"|"SZA R&B"|"SZA live"|"SZA videos"|"SZA music videos"|"music videos"|"vevo videos"|"streaming video"|"streaming music"',
#  'portugal the man|"portugal. the man"|"woodstock"|"feel it still"|"american music awards"|"ama"|"john gourley"|"feel it still band"',
#  'bts|"방탄소년단"|"amas"|"american music awards"|"ama"|"amas 2017 live stream"|"amas 2017 bts live"|"防弾少年団"|"interview"|"interviews"|"all"|"full"|"james corden"|"ellen"|"bts dna"|"ama\'s"|"selena gomez"|"wolves"|"christina aguilera"|"demi lovato"|"lady gaga"|"nicki minaj"|"dna"|"army"|"bts dna amas"|"bts dna amas 2017"|"first us performance"|"ellen degeneres"|"chainsmokers"|"jungkook"|"official"|"vevo"|"jimin"|"kim"|"suga"|"jin"|"j hope"|"japan"|"kpop"|"ansel"|"reaction"|"full performance"|"amas live"|"jimmy kimmel live"|"us debut"|"mic drop"|"btsxamas"',
#  ...]

# %% [markdown]
# list_tags_gb akan disatukan dengan fungsi join() agar menjadi string. String baru dengan nama string_tags_gb perlu dibuat terlebih dahulu dengan isi "|" agar "|" bertindak sebagai separator antar isi dari list setelah dilakukan join().

# %%
string_tags_gb = "|"

# %%
string_tags_gb = string_tags_gb.join(list_tags_gb)

# %% [markdown]
# Setelah dilakukan join, karakter " atau double quote perlu dihilangkan dengan fungsi replace()

# %%
string_tags_gb = string_tags_gb.replace('"', '')

# %% [markdown]
# String dikonversi menjadi lowercase untuk mempermudah penghitungan nantinya.

# %%
string_tags_gb = string_tags_gb.lower()

# %% [markdown]
# Kemudian fungsi split dilakukan terhadap karakter "|" untuk memisahkan antar teks dalam string tersebut dan menjadikannya array string.

# %%
string_tags_gb = string_tags_gb.split("|")

string_tags_gb
# Out:
# ['eminem',
#  'walk',
#  'on',
#  'water',
#  'aftermath/shady/interscope',
#  'rap',
#  'edsheeran',
#  'ed sheeran',
#  'acoustic',
#  'live',
#  'cover',
#  'official',
#  'remix',
#  'official video',
#  'lyrics',
#  'session',
#  'elbow',
#  'golden',
#  'slumbers',
#  'polydor',
#  'alternative',
#  'jennifer lopez ft. wisin',
#  'jennifer lopez ft. wisin music',
#  'jennifer lopez ft. wisin official video',
#  'jennifer lopez ft. wisin video',
#  'jennifer lopez ft. wisin video oficial',
#  'jennifer lopez ft. wisin nuevo video',
#  'jennifer lopez ft. wisin new video',
#  'amor',
#  'amor official video',
#  'official video',
#  'amor single',
#  'single',
#  'jennifer lopez ft. wisin new single',
#  'jennifer lopez ft. wisin single',
#  'jennifer lopez ft. wisin amor',
#  'jennifer',
#  'lopez',
#  'gucci mane',
#  'the weeknd',
#  'curve',
#  'official',
#  'music video',
#  'atlantic',
#  'records',
#  'trap',
#  'trap god',
#  '1017',
#  'gucci',
#  'mr davis',
#  'atlanta',
#  'rap',
#  'hip hop',
#  'bbc',
#  'music',
#  'bbc music',
#  'sam smith',
#  'wedding',
#  'sam smith at the bbc',
#  'at the bbc',
#  'camila cabello',
#  'camila',
#  'young thug',
#  'havana',
#  'fifth harmony',
#  '5h',
#  'harmonizers',
#  'crying in the club',
#  'omg',
#  'i have questions',
#  'know no better',
#  'lauren jauregui',
#  'dinah jane',
#  'normandi kordei',
#  'ally brooke',
#  'lele',
#  'pons',
#  'lelepons',
#  'shawn mendes',
#  'lele pons',
#  'lujuan james',
#  'influencers',
#  'instagram influencer',
#  'lele instagram',
#  'latina influencer',
#  'lelepons dance videos',
#  'lele pons dance battle',
#  'camila cabello feat. young thug',
#  'havana',
#  'pop',
#  'syco music/epic',
#  'selena gomez wolves',
#  'alone marshmello',
#  'marshmello - alone',
#  'marshmellow',
#  'you and me',
#  'marshmello music video',
#  'marshmello you and me',
#  'cooking with mello',
#  'silence',
#  'wolves',
#  'havana',
#  'nuevo musica',
#  'nueva canciones',
#  'khalid',
#  'selena',
#  'alan walker',
#  'marshmello amv',
#  'toon53',
#  'marshmello cartoon',
#  'cartoon',
#  'animated',
#  'animated music video',
#  'toons',
#  'cartoons',
#  'rick and morty',
#  'pickle rick',
#  'rollercoasters',
#  'roblox',
#  'marshmello roblox',
#  'naruto',
#  'marshmello singing',
#  'musically',
#  'top new songs',
#  'music',
#  'official',
#  'music video',
#  'bright',
#  'bright: the album',
#  'bright the album',
#  'bastille',
#  'world gone mad',
#  'atlantic records',
#  'will smith',
#  'orc',
#  'sharon needles',
#  'andy warhol is dead',
#  'battle axe',
#  'sharon',
#  'needles',
#  'andy',
#  'warhol',
#  'is',
#  'dead',
#  'battle',
#  'axe',
#  'drag',
#  'empire',
#  'of',
#  'the',
#  'sun',
#  'way',
#  'to',
#  'go',
#  'emi',
#  'alternative',
#  'eots',
#  'waay',
#  'too',
#  'goo',
#  'emipre of the sun',
#  'son',
#  'electronic',
#  'edm',
#  'australian',
#  'adm',
#  'aussie music. triplej',
#  'like a version',
#  'two leaves',
#  'flume',
#  'alison wonderland',
#  'cut copy',
#  'pnau',
#  'mgmt',
#  'hot chip',
#  'the presets',
#  'phoenix',
#  'hermitude',
#  'nobumichi asai',
#  'ryo kitabatake',
#  'sia snowman holiday',
#  'chayanne ft. ozuna',
#  'chayanne ft. ozuna music',
#  'chayanne ft. ozuna official video',
#  'chayanne ft. ozuna video',
#  'chayanne ft. ozuna video oficial',
#  'chayanne ft. ozuna nuevo video',
#  'chayanne ft. ozuna new video',
#  'choka choka official video',
#  'official video',
#  'choka choka single',
#  'single',
#  'chayanne ft. ozuna new single',
#  'chayanne ft. ozuna single',
#  'chayanne ft. ozuna choka choka',
#  'chayanne feat. ozuna',
#  'choka choka',
#  'latin pop',
#  'sony music latin',
#  'sigrid',
#  'strangers',
#  'island',
#  'records',
#  'pop',
#  'niall horan',
#  'niall',
#  'horan',
#  'too much to ask',
#  'too much too ask',
#  'to much to ask',
#  'to much too ask',
#  'tmta',
#  'too much to ask acoustic',
#  'too much too ask acoustic',
#  'to much to ask acoustic',
#  'to much too ask acoustic',
#  'tmta acoustic',
#  'acoustic',
#  'acoustic video',
#  'columbia',
#  'hip hop',
#  "remy ma feat. lil' kim",
#  'wake me up',
#  'power 106 hip hop interviews performance rap los angeles celebrity news',
#  'hip hop',
#  'hip-hop',
#  'west coast',
#  'rap',
#  'music',
#  'thirty',
#  'seconds',
#  'to',
#  'mars',
#  'walk',
#  'on',
#  'water',
#  'to',
#  'mars/interscope',
#  'records',
#  'alternative',
#  'thirty seconds to mars',
#  'thirty seconds to mars ellen',
#  '30 seconds to mars ellen',
#  'mars ellen',
#  'ellen',
#  'walk on water',
#  'thirty seconds to mars',
#  '30 seconds to mars walk on water',
#  'thirty seconds to mars walk on water',
#  'mars',
#  'mars walk on water',
#  'walk on water vid',
#  '30 sec to mars',
#  '30 secs to mars walk on water',
#  'walk on water video',
#  'official video',
#  'vid',
#  'the script',
#  'the script new single',
#  'the script arms open',
#  'the script arms open acoustic',
#  'the script arms open acoustic version',
#  'rain',
#  'hall of fame',
#  'breakeven',
#  'superheroes',
#  'rain lyrics',
#  'for the first time',
#  "the man who can't be moved",
#  'if you could see me now',
#  'arms open (acoustic)',
#  'columbia',
#  'pop',
#  'the script',
#  'columbia',
#  'harry styles',
#  'kiwi',
#  'pop',
#  'earmusic',
#  'live 2017',
#  'new album',
#  'music video',
#  'download',
#  'thunder',
#  'christmas day',
#  'rip it up',
#  'christmas',
#  'christmas song',
#  'danny bowes',
#  'virtual',
#  'self',
#  'neotrance',
#  'house',
#  'trance',
#  'electronic',
#  'electro',
#  'porter robinson',
#  'virtual self',
#  'virtualself',
#  'electronic music',
#  'ghost',
#  'voices',
#  'ghost voices',
#  'ghostvoices',
#  'pathselector',
#  'technic',
#  'angel',
#  'technic_angel',
#  'technicangel',
#  'porter',
#  'robinson',
#  'electronicmusic',
#  'visualizer',
#  'lyric video',
#  'official audio',
#  'audio',
#  '2017',
#  'new porter robinson',
#  'porter robinson 2017',
#  'lorde',
#  'bruce springsteen',
#  "i'm on fire",
#  '400 lux',
#  'christchurch',
#  'isaac theatre royal',
#  'liam',
#  'payne',
#  'bedroom',
#  'floor',
#  'capitol',
#  'pop',
#  '[none]',
#  'trap city',
#  'trapcity',
#  'trap',
#  'city',
#  'trap music',
#  'future bass',
#  'edm',
#  'electronic music',
#  'electronic dance music',
#  'alison wonderland - happy place',
#  'alison wonderland',
#  'happy place',
#  'alison wonderland happy place',
#  'happy place alison wonderland',
#  'kelela',
#  'blue',
#  'light',
#  'warp',
#  'records',
#  'electronic',
#  'pop',
#  'cj e&m',
#  'cjenm',
#  'cjenmmusic',
#  'k-culture',
#  'korean music',
#  'mv',
#  'music video',
#  'k-pop',
#  'kpop',
#  '뮤비',
#  '뮤직비디오',
#  '블락비',
#  'block b',
#  'shall we dance',
#  '블락비 (block b) - shall we dance mv',
#  'red velvet',
#  '레드벨벳',
#  '아이린',
#  '조이',
#  '슬기',
#  '웬디',
#  '예리',
#  'irene',
#  'joy',
#  'seulgi',
#  'wendy',
#  'yeri',
#  'peek-a-boo',
#  '피카부',
#  'chromeo',
#  'chromeo juice',
#  'juice',
#  'head over heels',
#  'chromeo head over heels',
#  'chromeo new single',
#  'chromeo new song',
#  'chromeo new album',
#  'chromeo the juice',
#  'you got the juice',
#  "you've got the juice",
#  'chromeo juice official video',
#  'chromeo music video',
#  'juice music video',
#  'pressin ya',
#  'chromeo new music',
#  'chromeo you got the juice',
#  "chromeo you've got the juice",
#  'chromeo juice video',
#  'chromeo juice official',
#  'chromeo single',
#  'chromeo 2017 single',
#  'chromeo juice song',
#  'funklordz',
#  'kpop',
#  'starship',
#  'loen',
#  '뮤비',
#  '스타쉽',
#  '티져',
#  'teaser',
#  '신곡',
#  'new',
#  'song',
#  '한류',
#  'hallyu',
#  '아이돌',
#  'idol',
#  '몬스타엑스',
#  'monsta x',
#  '컴백',
#  'comeback',
#  '더코드',
#  'the code',
#  'protocol terminal',
#  'monsta x mv',
#  'dramarama',
#  'monsta x beautiful',
#  'monsta x hero',
#  'monsta x fighter',
#  'monsta x minhyuk',
#  'monsta x shownu',
#  'monsta x kihyun',
#  'monsta x wonho',
#  'monsta x im',
#  'monsta x jooheon',
#  '몬엑',
#  '몬스타엑스 셔누',
#  '몬스타엑스 주헌',
#  '몬스타엑스 민혁',
#  '몬스타엑스 원호',
#  '몬스타엑스 형원',
#  '몬스타엑스 기현',
#  '몬스타엑스 아이엠',
#  'monsta x tresspass',
#  '무단침입',
#  '몬스타엑스 걸어',
#  'monsta x hyungwon',
#  '드라마라마',
#  '몬스타엑스 드라마라마',
#  '2cellos',
#  'luka sulic',
#  'stjepan hauser',
#  'cello',
#  'cellist',
#  'cellists',
#  'cover',
#  'glee',
#  'the piano guys',
#  'crossover',
#  '2 cellos',
#  'two cellos',
#  'hauser',
#  'ennio morricone',
#  'cinema paradiso',
#  'movie',
#  'film',
#  'soundtrack',
#  'classical',
#  'music',
#  'passion',
#  'oliver dragojevic',
#  'lso',
#  'london symphony orchestra',
#  'new album',
#  'score',
#  'yxng bane',
#  'yxng bane rihanna',
#  'yxng bane rihanna live',
#  'yxng bane artist to watch',
#  'yxng bane dscvr',
#  'yxng bane shape of you',
#  'yxng bane shape of you lyrics',
#  'yxng bane snapchat',
#  'yxng bane concert',
#  'yxng bane mixtape',
#  'yxng bane nottingham',
#  'afro-swing',
#  'rap',
#  'grime',
#  'dscvr',
#  'dscvr artist to watch 2018',
#  'ones to watch 2018',
#  'sound poll',
#  'vevo',
#  'vevo dscvr',
#  'kpop',
#  '1thek',
#  '원더케이',
#  'loen',
#  '로엔',
#  '뮤비',
#  '티져',
#  'mv',
#  'teaser',
#  '신곡',
#  'new',
#  'song',
#  '한류',
#  'hallyu',
#  'ロエン',
#  'ミュージック',
#  'ミュージックビデオ',
#  'ケーポップ',
#  '韓国の歌',
#  'アイドル',
#  '韓流',
#  '韓国',
#  '아이돌',
#  'idol',
#  'sonamoo',
#  '소나무',
#  'knew it',
#  '하이디',
#  '수민',
#  '의진',
#  '디애나',
#  '민재',
#  '뉴썬',
#  'high.d',
#  'sumin',
#  'min jae',
#  'd.ana',
#  'na hyun',
#  'eui jin',
#  'new sun',
#  '옆집소녀',
#  'deep blue eyes',
#  'ts',
#  '티에스',
#  'b.a.p',
#  'trcng',
#  'arvo',
#  'pärt',
#  'tabula',
#  'rasa',
#  'part',
#  'violin',
#  'concerto',
#  'violino',
#  'arvo pärt (musical artist)',
#  'sinduonitria',
#  'música',
#  'clássica',
#  'classica',
#  'musica',
#  'classical',
#  'music',
#  'minimalism',
#  'minimalismo',
#  'post malone',
#  'post malone rockstar',
#  'rockstar',
#  '21 savage',
#  'stoney',
#  'beerbongs & bentleys',
#  'beerbongs',
#  'bentleys',
#  'austin post',
#  'rockstar post malone',
#  'post malone rockstar ft 21 savage',
#  'post malone - rockstar',
#  '21 savage post malone',
#  'post malone 21 savage',
#  'post malone ft 21 savage',
#  'beerbongs and bentleys',
#  'newmusic',
#  'indie',
#  'bbc6music',
#  'alternative',
#  'field music',
#  'open here',
#  'ozuna',
#  'reggaeton',
#  'odisea',
#  'odisea the album',
#  'música sin fronteras',
#  'documentary',
#  'youtube documentary',
#  'documental',
#  'musica sin fronteras',
#  'taylor swift',
#  'call it what you want',
#  'reputation',
#  'migos',
#  'cardi b',
#  'cardi',
#  'nicki minaj',
#  'nicki',
#  'minaj',
#  'motorsport',
#  'motor',
#  'sport',
#  'motor sport',
#  'culture 2',
#  'hot97',
#  'hot97app',
#  'music',
#  'video',
#  'hip hop',
#  'rap',
#  'r&b',
#  'hip-hop',
#  'new york',
#  'ny',
#  'us',
#  'united states',
#  'hot97.com',
#  'zhu',
#  'exhale/stardust',
#  '(music',
#  'video)',
#  'mind',
#  'of',
#  'genius',
#  'club/dance',
#  'electronic',
#  'hip hop',
#  'lemon',
#  'n.e.r.d & rihanna',
#  'i am other/columbia',
#  'bystorm entertainment/rca records',
#  'miguel',
#  'r&b',
#  'told you so',
#  'vance joy',
#  'like gold',
#  'official audio',
#  'nation of two',
#  'maroon',
#  'a-trak',
#  'what',
#  'lovers',
#  'do',
#  '222',
#  'records/interscope',
#  'records',
#  'pop',
#  'chris',
#  'stapleton',
#  'scarecrow',
#  'in',
#  'the',
#  'garden',
#  'mercury',
#  'nashville',
#  'country',
#  'selena',
#  'gomez',
#  'marshmello',
#  'wolves',
#  'interscope',
#  'records',
#  'pop',
#  'madison',
#  'beer',
#  'say',
#  'it',
#  'to',
#  'my',
#  'face',
#  '(official',
#  'audio)',
#  'ditto',
#  'music',
#  'pop',
#  'don diablo',
#  'electronic music',
#  'electronic',
#  'arizona',
#  'take her place',
#  'future',
#  'edm',
#  'house',
#  'pop',
#  'cutting shapes',
#  'chill',
#  'on my mind',
#  'chemicals',
#  'lyric video',
#  'dont let go',
#  'don diably lyrics',
#  'arizona lyric video',
#  'wolves lyric video',
#  'new don diablo',
#  'don diablo id',
#  'don diablo amf',
#  'ade 2017',
#  'don diablo ade',
#  'the spectre',
#  'silence',
#  'hello there',
#  'crowd control',
#  'to the left left left',
#  'you can take her place tonight',
#  'luke',
#  'bryan',
#  'most',
#  'people',
#  'are',
#  'good',
#  'capitol',
#  'records',
#  'nashville',
#  'country',
#  'dodie',
#  'dodie interview',
#  'dodie ireland',
#  'dodie vevo',
#  'dodie live',
#  'dodie when',
#  'dodie hair',
#  'dodie glue',
#  'dodie 610',
#  'dodie losing soulmates',
#  'tourism ireland',
#  'vevo uk',
#  'dodie you',
#  'dodie live session',
#  'dodie intertwined',
#  'dodie mandela hall',
#  'dodie fans',
#  'ireland',
#  'northern ireland',
#  'new hip hop songs',
#  'rap',
#  'hip hop',
#  'wshh',
#  'wshh exclusive',
#  'quiet',
#  'milck',
#  'ickw',
#  'i cant keep quiet',
#  'milk',
#  'atlantic records',
#  'wmg',
#  'warner music group',
#  'new music',
#  'music video',
#  'womens march',
#  'taylor swift now',
#  'taylor swift',
#  'swifties',
#  'reputation',
#  'lwymmd',
#  'making of a song',
#  'marshmello',
#  'blocks',
#  'marshmello blocks',
#  'blocks music video',
#  'marshmello music video',
#  'roblox bully story',
#  'marshmello alone',
#  'roblox',
#  'cuphead',
#  'marshmello nightcore',
#  'marshmello musically',
#  'music for kids',
#  'happy music',
#  'videos that make you happy',
#  'sad songs',
#  'childrens music',
#  'joytime',
#  'marshmello joytime',
#  'frat bro',
#  'band',
#  'high school',
#  'crush',
#  'mellogang',
#  'marshmallow',
#  'noviembre 2017',
#  'musik elektronik',
#  'billboard',
#  'november 2017',
#  'nhạc điện tử hay nhất 2017',
#  'demi lovato',
#  'skyscraper',
#  'live lounge',
#  'bbc radio 1',
#  'eminem',
#  'walk',
#  'on',
#  'water',
#  'aftermath/shady/interscope',
#  'rap',
#  'tour doc',
#  'bruno mars',
#  '24k magic tour',
#  'world tour',
#  'havana',
#  'havana video',
#  'camila cabello',
#  'camila',
#  'documentary',
#  'tour documentary',
#  'youtube',
#  'hot97',
#  'hot97app',
#  'music',
#  'video',
#  'hip hop',
#  'rap',
#  'r&b',
#  'hip-hop',
#  'new york',
#  'ny',
#  'us',
#  'united states',
#  'hot97.com',
#  'iman',
#  'iman shumpert',
#  'teyana',
#  'teyana taylor',
#  'kanye west',
#  'fade',
#  'cavs',
#  'cavaliers',
#  'cleveland',
#  'elbow',
#  'golden',
#  'slumbers',
#  'polydor',
#  'alternative',
#  'jennifer lopez ft. wisin',
#  'jennifer lopez ft. wisin music',
#  'jennifer lopez ft. wisin official video',
#  'jennifer lopez ft. wisin video',
#  'jennifer lopez ft. wisin video oficial',
#  'jennifer lopez ft. wisin nuevo video',
#  'jennifer lopez ft. wisin new video',
#  'amor',
#  'amor official video',
#  'official video',
#  'amor single',
#  'single',
#  'jennifer lopez ft. wisin new single',
#  'jennifer lopez ft. wisin single',
#  'jennifer lopez ft. wisin amor',
#  'jennifer',
#  'lopez',
#  'edsheeran',
#  'ed sheeran',
#  'acoustic',
#  'live',
#  'cover',
#  'official',
#  'remix',
#  'official video',
#  'lyrics',
#  'session',
#  'gucci mane',
#  'the weeknd',
#  'curve',
#  'official',
#  'music video',
#  'atlantic',
#  'records',
#  'trap',
#  'trap god',
#  '1017',
#  'gucci',
#  'mr davis',
#  'atlanta',
#  'rap',
#  'hip hop',
#  '[none]',
#  'bbc',
#  'music',
#  'bbc music',
#  'sam smith',
#  'wedding',
#  'sam smith at the bbc',
#  'at the bbc',
#  'camila cabello',
#  'camila',
#  'young thug',
#  'havana',
#  'fifth harmony',
#  '5h',
#  'harmonizers',
#  'crying in the club',
#  'omg',
#  'i have questions',
#  'know no better',
#  'lauren jauregui',
#  'dinah jane',
#  'normandi kordei',
#  'ally brooke',
#  'lele',
#  'pons',
#  'lelepons',
#  'shawn mendes',
#  'lele pons',
#  'lujuan james',
#  'influencers',
#  'instagram influencer',
#  'lele instagram',
#  'latina influencer',
#  'lelepons dance videos',
#  'lele pons dance battle',
#  'camila cabello feat. young thug',
#  'havana',
#  'pop',
#  'syco music/epic',
#  'music',
#  'official',
#  'music video',
#  'bright',
#  'bright: the album',
#  'bright the album',
#  'bastille',
#  'world gone mad',
#  'atlantic records',
#  'will smith',
#  'orc',
#  'chayanne ft. ozuna',
#  'chayanne ft. ozuna music',
#  'chayanne ft. ozuna official video',
#  'chayanne ft. ozuna video',
#  'chayanne ft. ozuna video oficial',
#  'chayanne ft. ozuna nuevo video',
#  'chayanne ft. ozuna new video',
#  'choka choka official video',
#  'official video',
#  'choka choka single',
#  'single',
#  'chayanne ft. ozuna new single',
#  'chayanne ft. ozuna single',
#  'chayanne ft. ozuna choka choka',
#  'chayanne feat. ozuna',
#  'choka choka',
#  'latin pop',
#  'sony music latin',
#  'niall horan',
#  'niall',
#  'horan',
#  'too much to ask',
#  'too much too ask',
#  'to much to ask',
#  'to much too ask',
#  'tmta',
#  'too much to ask acoustic',
#  'too much too ask acoustic',
#  'to much to ask acoustic',
#  'to much too ask acoustic',
#  'tmta acoustic',
#  'acoustic',
#  'acoustic video',
#  'sia snowman holiday',
#  'empire',
#  'of',
#  'the',
#  'sun',
#  'way',
#  'to',
#  'go',
#  'emi',
#  'alternative',
#  'eots',
#  'waay',
#  'too',
#  'goo',
#  'emipre of the sun',
#  'son',
#  'electronic',
#  'edm',
#  'australian',
#  'adm',
#  'aussie music. triplej',
#  'like a version',
#  'two leaves',
#  'flume',
#  'alison wonderland',
#  'cut copy',
#  'pnau',
#  'mgmt',
#  'hot chip',
#  'the presets',
#  'phoenix',
#  'hermitude',
#  'nobumichi asai',
#  'ryo kitabatake',
#  'sigrid',
#  'strangers',
#  'island',
#  'records',
#  'pop',
#  'columbia',
#  ...]

# %%
# membuat kolom bernama tag yang berisikan array string string_tags_gb
dfGBmusic_tags = pd.DataFrame(string_tags_gb, columns=['tag'])

# %%
#membuat dataframe baru dengan value_counts yang menghitung berapa kali tag muncul dalam datasets dfGBmusic_tags
dfGBmusic_tags_count = pd.DataFrame(dfGBmusic_tags.tag.value_counts().reset_index())

#reset index dari 1
dfGBmusic_tags_count.index = dfGBmusic_tags_count.index + 1

#rename kolom
dfGBmusic_tags_count.columns = ['tag', 'tag_count']

print("TOP 5 TAG DI KATEGORI MUSIC GREAT BRITAIN")
dfGBmusic_tags_count.head(5)
# Out:
# TOP 5 TAG DI KATEGORI MUSIC GREAT BRITAIN
#            tag  tag_count
# 1          pop       2117
# 2        music       1612
# 3          rap       1507
# 4  music video       1326
# 5      hip hop       1188

# %% [markdown]
# #### Memvisualisasikan tag yang paling sering muncul di kategori Music negara Great Britain

# %% [markdown]
# Untuk memvisualisasikan tag-tag yang paling sering muncul, digunakan <b>WordCloud</b>.
#
# WordCloud dapat membaca dictionary yang berisikan teksnya lalu frekuensinya.
#
# Langkah pertama adalah mengkonversi dfGBmusic_tags_count menjadi dictionary. Dictionary terdiri dari data yang berasal dari kolom tag dan tag_count pada dataframe dfGBmusic_tags_count

# %%
# pembuatan dictionary yang berasal dari dataframe
dict_tags_music_GB = dict(zip(dfGBmusic_tags_count['tag'].tolist(), dfGBmusic_tags_count['tag_count'].tolist()))

dict_tags_music_GB
# Out:
# {'pop': 2117,
#  'music': 1612,
#  'rap': 1507,
#  'music video': 1326,
#  'hip hop': 1188,
#  'records': 1127,
#  'official video': 952,
#  'official': 869,
#  'atlantic records': 677,
#  'r&b': 655,
#  'the': 651,
#  'alternative': 638,
#  'hop': 587,
#  'hip': 550,
#  'dance': 488,
#  '[none]': 481,
#  'live': 465,
#  'new music': 454,
#  'video': 410,
#  'drake': 394,
#  'rca records label': 386,
#  'universal': 377,
#  'kpop': 377,
#  'worldstar': 359,
#  'latin': 347,
#  'mv': 343,
#  'rock': 339,
#  'ozuna': 333,
#  'single': 329,
#  'song': 326,
#  'hip-hop': 325,
#  'columbia': 310,
#  'bts': 299,
#  'bad bunny': 291,
#  'camila cabello': 287,
#  'new': 282,
#  'lyrics': 277,
#  'pop music': 267,
#  'ed sheeran': 265,
#  'remix': 264,
#  '뮤비': 262,
#  'cover': 255,
#  'new york': 251,
#  'latino': 246,
#  'official audio': 246,
#  'hip hop music': 243,
#  'edm': 239,
#  'electronic': 239,
#  'island': 238,
#  'migos': 235,
#  'marshmello': 233,
#  'official music video': 231,
#  'new song': 230,
#  'rap music': 227,
#  '2018': 227,
#  'diplo': 227,
#  'warner music group': 226,
#  'reggaeton': 225,
#  'havana': 224,
#  'eminem': 223,
#  'cardi b': 216,
#  'bbc': 213,
#  'taylor swift': 212,
#  'love': 211,
#  'j balvin': 210,
#  'live lounge': 203,
#  'acoustic': 201,
#  'you': 199,
#  'capitol': 199,
#  'wshh': 199,
#  'interscope': 189,
#  'james': 188,
#  'machine': 186,
#  'lyric video': 185,
#  'virgin': 182,
#  'album': 181,
#  'worldstarhiphop': 181,
#  'me': 179,
#  'idol': 179,
#  'llc': 177,
#  'quavo': 177,
#  'shawn mendes': 176,
#  '뮤직비디오': 176,
#  'selena gomez': 168,
#  'young thug': 167,
#  'smith': 166,
#  'metal': 163,
#  'demi lovato': 163,
#  'bangtan': 162,
#  'sza': 162,
#  'of': 159,
#  'offset': 158,
#  'kyle': 157,
#  'dua lipa': 153,
#  'teaser': 153,
#  'in': 151,
#  '방탄소년단': 151,
#  'emi': 151,
#  'trap': 151,
#  'k-pop': 150,
#  'future': 150,
#  'radio 1': 150,
#  'nicky jam': 149,
#  '아이돌': 149,
#  'jyp': 149,
#  'fbr': 147,
#  'fueled by ramen': 147,
#  'west coast hip hop': 146,
#  'interview': 145,
#  'urban': 145,
#  'maluma': 145,
#  'world star': 142,
#  'country': 142,
#  'youtube worldstar': 142,
#  'twice': 142,
#  'worldstar youtube': 142,
#  'wshh exclusive': 142,
#  'worldstarhiphop youtube': 142,
#  'world star hip hop': 142,
#  'youtube worldstarhiphop': 142,
#  'ariana grande': 140,
#  'new album': 140,
#  '빅히트': 140,
#  '방탄': 140,
#  'charlie puth': 139,
#  'friends': 137,
#  'kehlani': 136,
#  'ty dolla $ign': 134,
#  'ltd': 134,
#  'hallyu': 134,
#  'indie': 134,
#  'black panther': 132,
#  'stranger things': 131,
#  'david guetta': 131,
#  'money': 130,
#  'exclusive': 129,
#  'loen': 128,
#  '신곡': 128,
#  'my': 127,
#  'big': 127,
#  'perfect': 127,
#  'ty dolla sign': 126,
#  'ty dolla': 126,
#  'halsey': 125,
#  'polydor': 124,
#  'khalid': 124,
#  'worldstarhiphop channel': 123,
#  'astralwerks': 122,
#  'the voice': 121,
#  'ミュージック': 121,
#  'bighit': 120,
#  'logic': 120,
#  'fifth harmony': 120,
#  'miami': 120,
#  'united states': 119,
#  'hot97.com': 119,
#  'hot97': 119,
#  'ny': 119,
#  'gucci mane': 119,
#  'hot97app': 119,
#  'us': 119,
#  'charlie': 118,
#  '21 savage': 117,
#  'katy perry': 117,
#  'full album': 117,
#  '한류': 116,
#  '티져': 116,
#  'black panther trailer': 116,
#  'kelly': 116,
#  'daddy yankee': 116,
#  'nicki minaj': 113,
#  'camila': 113,
#  'panic! at the disco': 113,
#  'bay': 113,
#  'no': 111,
#  '2017': 111,
#  'dance/house/techno': 111,
#  'panic at the disco': 111,
#  '원더케이': 110,
#  'for': 110,
#  '로엔': 110,
#  '韓国': 110,
#  'アイドル': 110,
#  '韓流': 110,
#  '韓国の歌': 110,
#  'ロエン': 110,
#  '1thek': 110,
#  'ミュージックビデオ': 110,
#  'linkin park': 110,
#  'ケーポップ': 110,
#  'sia': 109,
#  'despacito': 109,
#  'disruptor records/columbia': 108,
#  'cello': 108,
#  'avicii': 108,
#  'new video': 107,
#  'wisin': 107,
#  'anne-marie': 106,
#  'bodak yellow': 106,
#  'all': 106,
#  'jason derulo': 105,
#  'vevo': 105,
#  'indie pop': 104,
#  'brendon urie': 103,
#  'christmas': 103,
#  'minaj': 103,
#  'kendrick lamar': 103,
#  'nicki': 103,
#  'patd': 103,
#  'machika': 103,
#  'puth': 102,
#  'dodie': 102,
#  'video oficial': 101,
#  'other': 101,
#  'soul': 101,
#  'never be the same': 101,
#  'cj e&m': 100,
#  'house': 100,
#  'soundtrack': 100,
#  'cjenmmusic': 100,
#  'korean music': 100,
#  'k-culture': 100,
#  'cjenm': 100,
#  'pink': 100,
#  'your': 100,
#  'dance music': 99,
#  'wolves': 98,
#  'dead': 97,
#  'post malone': 97,
#  'taylor gang': 97,
#  'geffen': 97,
#  'mine': 97,
#  'ty dollar sign': 97,
#  'beach house 3': 97,
#  'hollywood': 96,
#  'session': 96,
#  'bartier cardi': 96,
#  'my my my': 95,
#  'top dawg entertainment/rca records': 95,
#  'anitta': 95,
#  'kelly clarkson': 94,
#  'jay': 94,
#  'the chainsmokers': 94,
#  'dura': 94,
#  'yo gotti': 93,
#  'balvin': 93,
#  'new single': 93,
#  'bad': 93,
#  'dreamville': 93,
#  'will': 92,
#  'romeo santos': 91,
#  'pentatonix': 91,
#  'american idol': 91,
#  'big sean': 90,
#  'out': 90,
#  'mark': 90,
#  'xxl': 89,
#  'wonderland': 89,
#  'jam': 89,
#  'dirty computer': 89,
#  'sobredosis': 89,
#  'kygo': 89,
#  'entertainment': 89,
#  'janelle': 89,
#  'monae': 89,
#  'janelle monae': 89,
#  'back': 88,
#  'hiphop': 88,
#  'umle': 88,
#  'wild': 87,
#  'eone': 87,
#  'hopeless fountain kingdom': 87,
#  'boy': 87,
#  'hfk': 87,
#  'lil yachty': 86,
#  'beyonce': 86,
#  'odisea the album': 85,
#  "cam'ron": 85,
#  'pitch perfect': 85,
#  'hi bich': 85,
#  'odisea': 85,
#  'danielle bregoli': 85,
#  'amorfoda': 85,
#  'dj': 85,
#  'french montana': 85,
#  'grace vanderwaal': 84,
#  'syco music/columbia records': 84,
#  'young money': 84,
#  'new patd song': 83,
#  'pray for the wicked': 83,
#  'make me feel': 83,
#  'death of a bachelor': 83,
#  'lil wayne': 83,
#  'new panic album': 83,
#  'if': 83,
#  'psycho': 83,
#  'heavy metal': 83,
#  'yandel': 83,
#  'luis fonsi': 83,
#  'new panic song': 83,
#  'brendon urie vine': 83,
#  'new patd album': 83,
#  'p!atd': 83,
#  'rockstar': 82,
#  'flo rida': 82,
#  'beach house': 82,
#  'top': 82,
#  'apple music': 82,
#  'sam': 82,
#  'ty$': 82,
#  'kendrick': 82,
#  'clarkson': 82,
#  'dawg': 82,
#  'walk': 82,
#  'lamar': 82,
#  'cash me ousside': 81,
#  'white horse': 81,
#  'rnb': 81,
#  'catch me ousside': 81,
#  'drake gods plan': 81,
#  'heaux': 81,
#  'dr phil': 81,
#  'bhadbhade': 81,
#  'cash me outside': 81,
#  'new danielle bregoli': 81,
#  'hi bitch video': 81,
#  'catch me outside': 81,
#  'en': 81,
#  'these heaux': 81,
#  'swedish house mafia': 81,
#  'how bow dah': 81,
#  'what you know': 81,
#  '마크': 80,
#  'super duper': 80,
#  'independently popular': 80,
#  'k.i.d.': 80,
#  'ispy': 80,
#  'arcangel': 80,
#  'superduperkyle': 80,
#  'playinwitme': 80,
#  'the roots': 80,
#  'fall': 80,
#  'culture 2': 80,
#  'it': 80,
#  'funny': 80,
#  'natti natasha': 80,
#  'eminem 2017': 79,
#  'dk': 79,
#  'chan': 79,
#  'new eminem': 79,
#  'revival 2017': 79,
#  'el farsante remix': 78,
#  'instrumental': 77,
#  'ent./aftermath/interscope': 77,
#  'manuel turizo': 77,
#  'latin music': 77,
#  'will smith': 77,
#  'kyle harvey': 77,
#  'grammys': 77,
#  'rick ross': 77,
#  'annie mac': 77,
#  'youtube': 76,
#  'zion': 76,
#  'hi bich song': 76,
#  'love so soft': 76,
#  'finesse': 76,
#  'blake': 75,
#  'ps': 75,
#  'jyp entertainment': 75,
#  'walk on water': 75,
#  'electric lady': 75,
#  'latin pop': 75,
#  'emotion picture': 75,
#  'calvin harris': 75,
#  'world cup': 75,
#  'rapper': 75,
#  'chvrches': 75,
#  'to': 74,
#  'troye sivan': 74,
#  'oxls2xx0clg': 74,
#  'teddixs-uou': 74,
#  'rudimental': 74,
#  'watch now': 74,
#  'lpfgbcubmyk': 74,
#  'group home': 74,
#  '#dirtycomputer': 74,
#  'pwnefuakcbc': 74,
#  'culture': 73,
#  'rita ora': 73,
#  'bazzi mine': 73,
#  'justin timberlake': 73,
#  'pray': 73,
#  'j.': 73,
#  'bazzi': 73,
#  'yatra': 73,
#  'x-factor': 73,
#  'bazzi music': 73,
#  'meghan trainor': 73,
#  'dcd2': 73,
#  'mars': 72,
#  'beatbox': 72,
#  'boyz ii men': 72,
#  'ovo': 72,
#  'no excuses': 72,
#  'and': 72,
#  'electro': 72,
#  'epic': 72,
#  'snapchat': 72,
#  'atlantic': 72,
#  'ultra': 72,
#  'come through and chill': 72,
#  'world cup anthem': 72,
#  'remind me to forget': 72,
#  'toronto': 71,
#  'young': 71,
#  'meek mill': 71,
#  'guetta': 71,
#  'meaning of life': 71,
#  'payne': 71,
#  'liam': 71,
#  'behind the scenes': 70,
#  'troye': 70,
#  'clean bandit': 70,
#  'bpg/rvg/rca records': 69,
#  'ikon': 69,
#  'is': 69,
#  'wait': 69,
#  'g-eazy': 69,
#  'post malone rockstar': 69,
#  'pick up the phone': 69,
#  'wmg': 69,
#  'beautiful': 68,
#  'scott': 68,
#  'reputation': 68,
#  'mtjqq5rmley': 68,
#  'made-it': 67,
#  'download': 67,
#  'blood': 67,
#  'chun-li': 67,
#  'mike': 67,
#  '2 chainz': 66,
#  'los angeles': 66,
#  'slipknot': 66,
#  'pineapple': 66,
#  'anne': 66,
#  'mmg': 66,
#  'golden': 66,
#  'west coast rap': 66,
#  'marie': 66,
#  'audio': 66,
#  'me niego': 66,
#  '세븐틴': 65,
#  'joe burden': 65,
#  'seventeen': 65,
#  'musician': 65,
#  'real rap': 65,
#  'joel ortiz': 65,
#  'lil skies': 65,
#  'skies': 65,
#  'j. cole': 65,
#  'detroit': 65,
#  'prhyme': 65,
#  'pryhme': 65,
#  'token': 65,
#  'da': 65,
#  'jandora media': 65,
#  'halsy': 65,
#  'hip hopheads': 65,
#  'pharrell': 65,
#  'boblo': 65,
#  'dj premiere': 65,
#  'bad vs evil': 65,
#  'slaughterhouse': 65,
#  'detroit vs everybody': 65,
#  'royce': 65,
#  'pharrell williams': 65,
#  'premo': 65,
#  'nicholas jandora': 65,
#  'line': 65,
#  'eminiem': 65,
#  'tonight': 65,
#  '2 chains': 65,
#  'layers': 65,
#  'rap/hip-hop': 65,
#  'boat': 65,
#  'streets': 65,
#  "5'9": 65,
#  'idtay': 64,
#  'colors': 64,
#  'the middle': 64,
#  'mol': 64,
#  'want': 64,
#  'delicate': 64,
#  'humbug': 64,
#  'am': 64,
#  'camila cabello havana': 64,
#  'edsheeran': 64,
#  'lyric': 64,
#  'queen': 64,
#  'grey': 64,
#  'charlile puth kehlani song': 63,
#  'umgri': 63,
#  'alone': 63,
#  'charlie puth - done for me (feat. kehlani) [official audio]': 63,
#  'done for me official': 63,
#  'charlie puth - done for me (feat. kehlani)': 63,
#  'charlie puth done for me': 63,
#  'charlie puth kehlani': 63,
#  'charlie kehlani': 63,
#  'puth kehlani': 63,
#  'justice': 63,
#  'done for me (feat. kehlani)': 63,
#  'charlie puth kehlani done for me': 63,
#  'rupaul': 62,
#  'comedy': 62,
#  'bazzi beautiful': 62,
#  'kid': 62,
#  'blogger': 62,
#  'iggy': 62,
#  'look alive': 62,
#  'azalea': 62,
#  'travis': 62,
#  'crying in the club': 62,
#  'winner': 62,
#  'savior': 62,
#  'years': 62,
#  'guitar': 62,
#  'tekashi69': 61,
#  '6ix9ine 2018': 61,
#  'tde': 61,
#  '6ix9ine music': 61,
#  'day 69': 61,
#  'documentary': 61,
#  'j balvin ahora': 61,
#  'calum': 61,
#  'pop 2018': 61,
#  '6ix9ine': 61,
#  'amor foda': 61,
#  'dc': 61,
#  '1942': 61,
#  'wiz khalifa': 61,
#  'florida': 61,
#  'alesso': 61,
#  'twice mv': 60,
#  '트와이스 m/v': 60,
#  'twice music video': 60,
#  'super junior': 60,
#  'de la ghetto': 60,
#  '트와이스 뮤직비디오': 60,
#  '트와이스 mv': 60,
#  'twice 뮤비': 60,
#  'twice m/v': 60,
#  'oprah disney': 60,
#  '트와이스 뮤비': 60,
#  'im': 60,
#  '트와이스': 60,
#  'ebro': 60,
#  'mixtape': 60,
#  'sivan': 60,
#  'kanye west': 60,
#  'sure thing': 59,
#  'metallica': 59,
#  'aftermath/shady/interscope': 59,
#  'recordings': 59,
#  'eminem revival': 59,
#  'first time': 59,
#  'def': 59,
#  'marshmallow': 59,
#  'kids in love': 59,
#  'natti': 59,
#  'vai': 59,
#  'stargazing': 59,
#  'syco music': 59,
#  'stefflon don': 59,
#  'malone': 59,
#  'post': 59,
#  'new eminem 2017': 59,
#  'sky walker': 59,
#  'natasha': 59,
#  'stole the show': 59,
#  'firestone': 59,
#  'p!nk': 59,
#  'kygo & miguel': 59,
#  'bi': 58,
#  'river': 58,
#  'oficial': 58,
#  'bobby': 58,
#  'mamacita': 58,
#  'june': 58,
#  '바비': 58,
#  'seconds': 58,
#  'beer bongs and bentleys': 58,
#  '김바비': 58,
#  '몬스타엑스': 58,
#  'florence': 58,
#  'kevin': 57,
#  'scott hoying': 57,
#  'colors official video': 57,
#  'mitch grassi': 57,
#  'sing-off': 57,
#  'marshmello silence': 57,
#  'malandra': 57,
#  'olusola': 57,
#  'the sing-off': 57,
#  'marshmello alone': 57,
#  'bbc radio 1': 57,
#  'avi kaplan': 57,
#  'shawn stockman': 57,
#  'ptxofficial': 57,
#  'cellobox': 57,
#  'chorus': 57,
#  'lil peep': 57,
#  'kirstie maldonado': 57,
#  'singing': 57,
#  'sing': 57,
#  'choir': 57,
#  'a cappella': 57,
#  'harmony': 57,
#  'cole': 57,
#  'singing competition': 57,
#  'ben folds 5': 57,
#  'acappela': 57,
#  'ptx': 57,
#  'ben folds': 57,
#  'atm': 57,
#  'domino': 57,
#  'acapella': 57,
#  'reality tv': 57,
#  'k-o.': 57,
#  'mike shinoda': 57,
#  'sara bareilles': 57,
#  'voice': 57,
#  'penatonix': 57,
#  'lil boat': 56,
#  'the middle video': 56,
#  'clip': 56,
#  'electronic music': 56,
#  'shine': 56,
#  'corazon': 56,
#  'r&b/soul': 56,
#  'bum bum tam tam': 56,
#  'new rules': 55,
#  'got7': 55,
#  'aftermath': 55,
#  'concert': 55,
#  'maroon': 55,
#  'moby': 55,
#  'fifa': 55,
#  'jackson': 55,
#  'low life': 55,
#  'riddim': 55,
#  'coca cola': 55,
#  'takeoff': 55,
#  'mink flow': 55,
#  'mask off': 55,
#  'zedd': 55,
#  'the weeknd': 54,
#  'madonna': 54,
#  'idgaf': 54,
#  'dancing': 54,
#  'kylie': 54,
#  'kylie minogue': 54,
#  'new music from panic at the disco': 53,
#  'spotify': 53,
#  'marshmello friends': 53,
#  'dedication 6': 53,
#  'jaden': 53,
#  'rca records': 53,
#  'brendon urie patd': 53,
#  'brendon urie vine high note': 53,
#  'decaydance': 53,
#  'rockabye': 53,
#  'violin': 53,
#  'john mayer': 53,
#  'lady': 53,
#  'weezy': 53,
#  'musica en espanol': 53,
#  'calvin harris dua lipa one kiss': 53,
#  'world cup song': 52,
#  'calvin harris one kiss': 52,
#  'jay rock': 52,
#  'fifa song': 52,
#  'thmvmnt': 52,
#  'calvin harris nuh ready': 52,
#  'hyungwon': 52,
#  '민혁': 52,
#  'shownu': 52,
#  'top 40': 52,
#  '기현': 52,
#  'dirty': 52,
#  'tmz': 52,
#  'party': 52,
#  'calvin harris summer': 52,
#  '몬베베': 52,
#  'bystorm entertainment/rca records': 52,
#  '아이엠': 52,
#  'minhyuk': 52,
#  '형원': 52,
#  'babymetal': 52,
#  '주헌': 52,
#  'monbebe': 52,
#  '원호': 52,
#  'childish gambino': 52,
#  'jooheon': 52,
#  'wonho': 52,
#  'kihyun': 52,
#  'calvin harris feels': 52,
#  '셔누': 52,
#  'ps)': 51,
#  'brytiago': 51,
#  'miguel': 51,
#  'sugababes': 51,
#  'drag': 51,
#  'andrew bazzi': 51,
#  'jess glynne': 51,
#  'artist': 51,
#  'sony music latin': 51,
#  'natti natasha x bad bunny': 51,
#  '(tde/isr': 51,
#  'rich': 51,
#  'spice girls': 51,
#  'eminem single': 51,
#  'bananrama': 51,
#  'you so fucking precious when you smile': 51,
#  'girls aloud': 51,
#  'ty dollar': 51,
#  'all saints': 51,
#  'diva': 51,
#  'family': 51,
#  'dua': 50,
#  'locomotion': 50,
#  '희철': 50,
#  "can't get you out of my head": 50,
#  'into the blue': 50,
#  '도겸': 50,
#  'all the lovers': 50,
#  'i should be so lucky': 50,
#  'fever': 50,
#  'tears': 50,
#  'on a night like this': 50,
#  'hit': 50,
#  'in your eyes': 50,
#  'spinning around': 50,
#  '호시': 50,
#  'trance': 50,
#  '승관': 50,
#  'republic/universal/fsf': 50,
#  'jorja smith': 50,
#  'afrojack': 50,
#  'nct': 50,
#  'the good side': 50,
#  'sony': 50,
#  '슈퍼주니어': 50,
#  'loco-motion': 50,
#  'birdman': 49,
#  'jaden smith': 49,
#  'kod': 49,
#  'miguel feat. j. cole & salaam remi': 49,
#  'bunny': 49,
#  'a$ap rocky': 49,
#  'fake love': 49,
#  'mad': 49,
#  'lauv': 49,
#  'kill our demons': 49,
#  'king overdosed': 49,
#  'kids on drugs': 49,
#  'j cole': 49,
#  'ultra music': 49,
#  '지성': 49,
#  'thirty seconds to mars': 49,
#  'harmonizers': 49,
#  'sugarland': 49,
#  'top dawg entertainment': 49,
#  'jisung': 49,
#  'bloom': 49,
#  'jazz': 49,
#  'nuevo video': 48,
#  'beats 1': 48,
#  'edm drops': 48,
#  'shotsstudios': 48,
#  'in my blood': 48,
#  'bastille': 48,
#  'chainsmokers': 48,
#  'anwar': 48,
#  'rock music': 48,
#  'tori kelly': 48,
#  'brazil': 48,
#  'anitta vai malandra alesso koyu remix with anwar jibawi': 48,
#  'alesso anitta is that for me koyu remix official video': 48,
#  'drops': 48,
#  'culture ii': 48,
#  'candy pop': 48,
#  'what': 48,
#  'mendes': 48,
#  'alesso anitta is that for me sylvain armand remix official video': 48,
#  'singer': 48,
#  'everybody hates me': 48,
#  'yg': 48,
#  'genius': 47,
#  'rae': 47,
#  'world': 47,
#  '5 seconds of summer': 47,
#  'janelle monáe': 47,
#  'shawn': 47,
#  'wedding': 47,
#  '5sos': 47,
#  'miracle': 47,
#  'i have questions': 47,
#  'farruko': 47,
#  'all da smoke': 47,
#  'james arthur': 47,
#  'funny memes': 47,
#  'juicy j': 47,
#  'ballad': 47,
#  'man of the woods': 47,
#  'lennox': 46,
#  '드라마라마': 46,
#  'lele': 46,
#  'post traumatic': 46,
#  '프로듀스101': 46,
#  'partynextdoor': 46,
#  'zion & lennox': 46,
#  'lgbt': 46,
#  'wins and losses': 46,
#  'pons': 46,
#  'hola': 46,
#  'mgmt': 46,
#  'cuatro babys': 46,
#  'want you back': 46,
#  'marshmello spotlight': 46,
#  'mad decent': 46,
#  'piano': 46,
#  'tessa thompson': 46,
#  'django jane': 46,
#  'zion y lennox': 46,
#  'la player': 46,
#  'sremmurd': 46,
#  'weeknd': 46,
#  'justin bieber': 46,
#  'alternative/indie': 46,
#  'vista': 46,
#  'jxmmi': 46,
#  'meek mill music': 46,
#  'pynk': 46,
#  'wondaland': 46,
#  'dramarama': 46,
#  'fall thru': 46,
#  'flohola': 46,
#  'concord': 46,
#  'bandolera': 46,
#  'jennifer lopez': 46,
#  'meek': 46,
#  'loma': 46,
#  'michael clifford': 46,
#  'luke hemmings': 46,
#  'ashton irwin': 46,
#  'dj khaled': 46,
#  'calum hood': 46,
#  'umf': 45,
#  'shy glizzy': 45,
#  'lego': 45,
#  'patek water': 45,
#  '강다니엘': 45,
#  'jin': 45,
#  'performance': 45,
#  'future & young thug': 45,
#  'end game': 45,
#  'sade': 45,
#  'super slimey': 45,
#  'ditto': 45,
#  '워너원': 45,
#  'hndrxx': 45,
#  'ty dollar $ign': 45,
#  'epic/300/atlantic recording corporation': 45,
#  'emo': 45,
#  '티저': 45,
#  'dj snake': 45,
#  'maluma new single': 44,
#  '김진우': 44,
#  'ric flair drip': 44,
#  'radio': 44,
#  'jungkook': 44,
#  '강승윤': 44,
#  '송민호': 44,
#  'mix': 44,
#  'chill': 44,
#  'vlogger': 44,
#  '이승훈': 44,
#  'these hoes': 44,
#  'martin garrix': 44,
#  '트와이스 music video': 44,
#  'atlanta': 44,
#  'maluma official video': 44,
#  'with': 44,
#  'maluma music': 44,
#  'cosmic': 44,
#  'why dont we': 44,
#  'jimin': 44,
#  'garrix': 44,
#  'tell me you love me': 44,
#  'tour': 44,
#  'gaga': 44,
#  'soundtracks': 44,
#  'posty': 44,
#  'suga': 44,
#  'singer/songwriter': 44,
#  'cabello': 44,
#  'twice 뮤직비디오': 44,
#  'bazi': 44,
#  '위너': 44,
#  'records/interscope': 43,
#  'sebastián': 43,
#  'stars': 43,
#  'selena': 43,
#  'pasek and paul': 43,
#  'marshmello wolves': 43,
#  'edc': 43,
#  '222': 43,
#  '진영': 42,
#  'lele pons': 42,
#  '_glpefqmlzi': 42,
#  'desiigner': 42,
#  'nsync': 42,
#  '하성운': 42,
#  'lil durk': 42,
#  'amor': 42,
#  'bronx': 42,
#  'got7 jb': 42,
#  '갓세븐': 42,
#  '갓세븐 뱀뱀': 42,
#  '김재환': 42,
#  'voicenotes': 42,
#  'got7 jinyoung': 42,
#  'one kiss': 42,
#  '영재': 42,
#  'yugyeom': 42,
#  'youngjae': 42,
#  'quality': 42,
#  'control': 42,
#  'janelle monae and tessa thompson': 42,
#  'jb': 42,
#  'bad boy records': 42,
#  'jay z': 42,
#  'got7 bambam': 42,
#  'suicidal official video': 42,
#  '갓세븐 마크': 42,
#  'blackpanther': 42,
#  '라이관린': 42,
#  '갓세븐 유겸': 42,
#  'calvin harris dua lipa': 42,
#  'flowers': 42,
#  'got7 mark': 42,
#  'got7 yugyeom': 42,
#  '갓세븐 잭슨': 42,
#  'lil pump': 42,
#  '배진영': 42,
#  '잭슨': 42,
#  '태일': 42,
#  '뱀뱀': 42,
#  'bambam': 42,
#  '갓세븐 영재': 42,
#  'calvin harris slide': 42,
#  'lil durk 2018': 42,
#  'got7 jackson': 42,
#  'lil durk music': 42,
#  'gomez': 42,
#  '황민현': 42,
#  '박지훈': 42,
#  '유겸': 42,
#  '갓세븐 진영': 42,
#  '이대휘': 42,
#  '윤지성': 42,
#  '옹성우': 42,
#  'broadway': 41,
#  'cnco': 41,
#  'australia': 41,
#  'flames': 41,
#  'jbalvin': 41,
#  'sivann': 41,
#  'bbc music': 41,
#  'troy': 41,
#  'cnco nuevo sencillo': 41,
#  'i.m': 41,
#  'recorded': 41,
#  'cnco video oficial': 41,
#  'cnco music': 41,
#  'kanye': 41,
#  'blomm': 41,
#  'pty': 41,
#  'jv-old': 41,
#  'republic': 41,
#  'kiss': 41,
#  '“full album”': 41,
#  'blue neighbourhood': 41,
#  'sivam': 41,
#  'cnco single': 41,
#  'cnco official video': 41,
#  'youth': 41,
#  'daniel caesar': 41,
#  'cnco nuevo video': 41,
#  ...}

# %%
wc = WordCloud(width=800, height=600, background_color ='white').generate_from_frequencies(dict_tags_music_GB)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(wc)
plt.axis('off')
plt.title("WordCloud dari tag di kategori music Great Britain", fontsize=20)

plt.show()

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## B. BOXPLOTTING ABSOLUTE VALUE BERDASARKAN KATEGORI DATA VIDEO GREAT BRITAIN

# %% [markdown]
# Berikut adalah data jumlah viewer region Great Britain apabila divisualisasikan dengan boxplot. Karena data terlalu beragam, outliernya terlalu tinggi dan tidak dapat dilihat dengan baik.

# %% [markdown]
# ### 1B. Boxplotting Absolute Value Viewer Berdasarkan Kategori Data Video Great Britain

# %%
# list jumlah views wilayah Great Britain berdasarkan id pada dfGBcategory
data_view_gb_boxplot = [gGBvideo.get_group(items)['views'].values for items in dfGBcategory['id']]

# %%
fig = plt.figure(1, figsize=(15, 15))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(data_view_gb_boxplot)

# penamaan x tick berdasarkan id kategori Great Britain
ax.set_xticklabels(dfGBcategory['category'], rotation='vertical')

# penamaan judul
plt.title("ABSOLUTE VALUE VIEWER WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# Karena setelah dilakukan boxplotting outlier terlihat terlalu banyak maka diputgbkan untuk dicoba dilakukan outlier removal dengan metode z-score dan IQR pada salah satu kategori yaitu Entertainment yang mana ada di urutan 9 pada array a.

# %% [markdown]
# #### Testing Z-Score Viewer Salah Satu Kategori Video Great Britain Yaitu Entertainment

# %%
data_view_gb_boxplot = {
    
    # id kategori
    'id' : [items for items in dfGBcategory['id']],
    # nama kategori
    'category':[items for items in dfGBcategory['category']],
    #penonton tertinggi
    'viewer':[gGBvideo.get_group(items)['views'].values for items in dfGBcategory['id']],
    'median':[statistics.median(gGBvideo.get_group(items)['views'].values) for items in dfGBcategory['id']]
}

dfViewGBboxplot = pd.DataFrame(data_view_gb_boxplot)

# sort by median
dfViewGBboxplot = dfViewGBboxplot.sort_values(by="median",ascending=False).reset_index(drop=True)

dfViewGBboxplot
# Out:
#     id               category  \
# 0   10                  Music
# 1   43                  Shows
# 2   23                 Comedy
# 3    1       Film & Animation
# 4    2       Autos & Vehicles
# 5   24          Entertainment
# 6   28   Science & Technology
# 7   29  Nonprofits & Activism
# 8   15         Pets & Animals
# 9   27              Education
# 10  17                 Sports
# 11  22         People & Blogs
# 12  20                 Gaming
# 13  26          Howto & Style
# 14  25        News & Politics
# 15  19        Travel & Events
#
#                                                viewer         median
# 0   [17158579, 33523622, 154494, 9548677, 946859, ... 2980744.000000
# 1   [876996, 987708, 1080101, 1154486, 1217887, 13... 1498767.500000
# 2   [3371669, 3578502, 359120, 189374, 10676, 2820... 1278302.500000
# 3   [2794165, 3037613, 333552, 44921, 750287, 2841... 1144917.000000
# 4   [704363, 109148, 1530286, 803844, 111759, 1546... 1044150.000000
# 5   [1053632, 1182775, 728547, 2237404, 5541767, 2...  786954.000000
# 6   [1575525, 47610, 665232, 1703026, 3701763, 164...  715286.000000
# 7   [19270, 30870, 40905, 48984, 55794, 61291, 650...  672604.000000
# 8   [426078, 467804, 490300, 512261, 43009, 535958...  565055.000000
# 9   [269950, 2088254, 280864, 2108637, 284457, 212...  402504.000000
# 10  [27833, 306724, 86296, 156822, 146530, 33746, ...  346392.000000
# 11  [1164201, 110769, 2464, 422874, 181351, 113988...  321208.000000
# 12  [1062094, 747313, 226202, 99578, 7309863, 7278...  309154.500000
# 13  [7224515, 300617, 2063667, 238843, 332967, 219...  263412.000000
# 14  [9815, 254314, 3308, 159065, 229753, 1160827, ...  229753.000000
# 15  [1932429, 2200529, 2374145, 2533102, 19451, 27...  218176.000000

# %%
data_ent_gb_view = {
    'viewer' : dfViewGBboxplot.loc[9, 'viewer'],
    'z-score' : stats.zscore(dfViewGBboxplot.loc[9, 'viewer'])
}

dfEntertainViewTest = pd.DataFrame(data_ent_gb_view)

# %%
# Membuat Dataframe Baru yang telah difilter tanpa outlier
dfEntertainViewTestz = dfEntertainViewTest[dfEntertainViewTest['z-score'] < 3]

dfEntertainViewTestz
# Out:
#       viewer   z-score
# 0     269950 -0.338051
# 1    2088254  0.537262
# 2     280864 -0.332797
# 3    2108637  0.547074
# 4     284457 -0.331067
# ..       ...       ...
# 452   175082 -0.383719
# 453   192004 -0.375573
# 454   237154 -0.353839
# 455   280782 -0.332837
# 456   302344 -0.322457
#
# [435 rows x 2 columns]

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfEntertainViewTestz['viewer'].values)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("TESTING BOXPLOT VIEWERS KATEGORI ENTERTAINMENT GREAT BRITAIN SETELAH OUTLIER REMOVAL DENGAN Z-SCORE", fontsize=14)

plt.ylabel("Jumlah Views", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Views')

# %% [markdown]
# Setelah dilakukan outlier removal dengan Z-Score masih terlihat bahwa outlier dianggap masih terlalu banyak hingga sulit untuk dibaca, maka diputgbkan untuk mencoba dilakukan outlier removal dengan IQR

# %% [markdown]
# Step untuk mendeteksi outlier salah satunya adalah dengan menemukan range bawah dan atas dari suatu data dengan cara berikut :
# 1. Mengurutkan data dari nilai terendah
# 2. Menghitung Q1 (kuartil 1)
# 3. Menghitung Q3 (kuartil 3)
# 4. Menghitung IQR = (Q3 - Q1)
# 5. Menemukan range bawah data = Q1 -(1.5 * IQR)
# 6. Menemukan range atas data = Q3 + (1.5 * IQR)

# %%
Q1_test_ent_GB = dfEntertainViewTest.viewer.quantile(0.25)
Q3_test_ent_GB = dfEntertainViewTest.viewer.quantile(0.75)
IQR_test_ent_GB = Q3_test_ent_GB - Q1_test_ent_GB
lower_test_ent_GB = Q1_test_ent_GB  - (1.5 * IQR_test_ent_GB)
upper_test_ent_GB =  Q3_test_ent_GB + (1.5 * IQR_test_ent_GB)

print("IQR Ent Great Britain")
print("IQR =", IQR_test_ent_GB)
print("Lower =", lower_test_ent_GB)
print("Upper =", upper_test_ent_GB)
# Out:
# IQR Ent Great Britain
# IQR = 418598.0
# Lower = -435893.0
# Upper = 1238499.0

# %%
dfEntertainViewTest_IQRView = dfEntertainViewTest[(dfEntertainViewTest.viewer < upper_test_ent_GB) & (dfEntertainViewTest.viewer > lower_test_ent_GB)]

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfEntertainViewTest_IQRView['viewer'].values)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT VIEWERS KATEGORI ENTERTAINMENT GREAT BRITAIN SETELAH OUTLIER REMOVAL DENGAN IQR", fontsize=14)

plt.ylabel("Jumlah Views", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Views')

# %% [markdown]
# Setelah dilakukan outlier removal dengan IQR masih terlihat bahwa outlier masih cukup sulit untuk dibaca, di sini akhirnya diputgbkan untuk <b>menampilkan boxplot tanpa outlier</b>.

# %%
fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfViewGBboxplot['viewer'], showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori dfViewGBboxplot
ax.set_xticklabels(dfViewGBboxplot['category'], rotation='vertical')

# penamaan judul
plt.title("ABSOLUTE VALUE VIEWER WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# ### 2B. Boxplotting Absolute Value Likes Berdasarkan Kategori Data Video Great Britain

# %%
# membuat dataframe absolute value likes+median
data_likes_gb_boxplot = {
    
    # id diambil dari dfGBcategory
    'id' : [items for items in dfGBcategory['id']],
    # nama kategori
    'category':[items for items in dfGBcategory['category']],
    #penonton tertinggi
    'likes':[gGBvideo.get_group(items)['likes'].values for items in dfGBcategory['id']],
    #median
    'median':[statistics.median(gGBvideo.get_group(items)['likes'].values) for items in dfGBcategory['id']]
}

dfLikesGBboxplot= pd.DataFrame(data_likes_gb_boxplot)

# sort by median
dfLikesGBboxplot = dfLikesGBboxplot.sort_values(by="median",ascending=False).reset_index(drop=True)

# %%
fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfLikesGBboxplot['likes'], showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori dfLikesGBboxplot
ax.set_xticklabels(dfLikesGBboxplot['category'], rotation='vertical')

# penamaan judul
plt.title("ABSOLUTE VALUE LIKES WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# ### 3B. Boxplotting Absolute Value Dislikes Berdasarkan Kategori Data Video Great Britain

# %%
# membuat dataframe absolute value dislikes+median
data_dislikes_gb_boxplot = {
    
    # id diambil dari dfGBcategory kolom 'id'
    'id' : [items for items in dfGBcategory['id']],
    # nama kategori diambil dari dfGBcategory kolom 'category'
    'category':[items for items in dfGBcategory['category']],
    #penonton tertinggi
    'dislikes':[gGBvideo.get_group(items)['dislikes'].values for items in dfGBcategory['id']],
    #median
    'median':[statistics.median(gGBvideo.get_group(items)['dislikes'].values) for items in dfGBcategory['id']]
}

dfDislikesGBboxplot= pd.DataFrame(data_dislikes_gb_boxplot)

# sort by median
dfDislikesGBboxplot = dfDislikesGBboxplot.sort_values(by="median",ascending=False).reset_index(drop=True)

# %%
fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfDislikesGBboxplot['dislikes'], showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori Canada
ax.set_xticklabels(dfDislikesGBboxplot['category'], rotation='vertical')

# penamaan judul
plt.title("ABSOLUTE VALUE DISLIKES WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# ### 4B. Boxplotting Absolute Value Jumlah Komentar Berdasarkan Kategori Data Video Great Britain

# %%
# membuat dataframe absolute value comments+median
data_comments_gb_boxplot = {
    
    # id kategori
    'id' : [items for items in dfGBcategory['id']],
    # nama kategori
    'category':[items for items in dfGBcategory['category']],
    #penonton tertinggi
    'comments':[gGBvideo.get_group(items)['comment_count'].values for items in dfGBcategory['id']],
    #median
    'median':[statistics.median(gGBvideo.get_group(items)['comment_count'].values) for items in dfGBcategory['id']]
}

dfCommentsGBboxplot= pd.DataFrame(data_comments_gb_boxplot)

# sort by median
dfCommentsGBboxplot = dfCommentsGBboxplot.sort_values(by="median",ascending=False).reset_index(drop=True)

# %%
fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfCommentsGBboxplot['comments'], showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori Canada
ax.set_xticklabels(dfCommentsGBboxplot['category'], rotation='vertical')

# penamaan judul
plt.title("ABSOLUTE VALUE COMMENTS WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## C. BOXPLOTTING RELATIVE VALUE BERDASARKAN KATEGORI DATA VIDEO GREAT BRITAIN
# Karena melakukan boxplotting terhadap absolute value untuk jumlah views, likes, dislikes, dan comments tidak dapat dilihat dengan baik karena data terlalu diverse. Maka diputgbkan untuk melakukan boxplotting likes, dislikes, dan comments terhadap views untuk setiap video kemudian dikalikan 100 agar range value terjaga mulai dari 0 hingga 100.
#
#
# <b>Operasinya adalah sebagai sebagai berikut :<br/>
# - Jumlah Likes / Jumlah Views * 100<br/>
# - Jumlah Dislikes / Jumlah Views * 100<br/>
# - Jumlah Comments / Jumlah Views * 100<br/></b>

# %% [markdown]
# Untuk itu maka dataframe video perlu dimodifikasi dengan menghapgb kolom yang tidak diperlukan dan menambahkan kolom baru dari setiap operasi yang dilakukan

# %%
# drop kolom yang tidak perlu
dfGB = dfGBvideos.drop([
    'trending_date','channel_title','publish_time','tags','thumbnail_link','comments_disabled','ratings_disabled',
  'video_error_or_removed','description'], axis=1)

# %%
# Menambah kolom likes/views
dfGB['likes/views(%)'] = dfGB['likes']/dfGB['views']*100

# %%
# Menambah kolom dislikes/views
dfGB['dislikes/views(%)'] = dfGB['dislikes']/dfGB['views']*100

# %%
# Menambah kolom comments/views
dfGB['comments/views(%)'] = dfGB['comment_count']/dfGB['views']*100

# %% [markdown]
# Berikut adalah data video Great Britain setelah dimodifikasi. Dataframe ditambah kolom sebagai berikut :
# <b>
# - likes/views
# - dislikes/views
# - comments/views
# </b>
# semua dalam persen (%)

# %%
dfGB.head()
# Out:
#       video_id                                              title  \
# 0  Jw1Y-zhQURU      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1  3s1rvMFUweQ          Taylor Swift: …Ready for It? (Live) - SNL
# 2  n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  PUTEiSjKwJU  Goals from Salford City vs Class of 92 and Fri...
# 4  rHwDegptbI4  Dashcam captures truck's near miss with child ...
#
#    category_id     views   likes  dislikes  comment_count  likes/views(%)  \
# 0           26   7224515   55681     10247           9479        0.770723
# 1           24   1053632   25561      2294           2757        2.425989
# 2           10  17158579  787420     43420         125882        4.589075
# 3           17     27833     193        12             37        0.693421
# 4           25      9815      30         2             30        0.305655
#
#    dislikes/views(%)  comments/views(%)
# 0           0.141837           0.131206
# 1           0.217723           0.261666
# 2           0.253051           0.733639
# 3           0.043114           0.132936
# 4           0.020377           0.305655

# %% [markdown]
# Karena data video telah dimodifikasi, maka pengelompokan ulang berdasarkan id kategori perlu dilakukan kembali

# %%
gGBvideo = dfGB.groupby('category_id')

# %%
data_relative_views_gb = {
    
    'id' : [items for items in dfGBcategory['id']],
    'category' : [items for items in dfGBcategory['category']],
    'likes/views(%)': [gGBvideo.get_group(items)['likes/views(%)'].values for items in dfGBcategory['id']],
    'dislikes/views(%)': [gGBvideo.get_group(items)['dislikes/views(%)'].values for items in dfGBcategory['id']],
    'comments/views(%)': [gGBvideo.get_group(items)['comments/views(%)'].values for items in dfGBcategory['id']],
    'median_likes/views(%)': [statistics.median(gGBvideo.get_group(items)['likes/views(%)'].values) for items in dfGBcategory['id']],
    'median_dislikes/views(%)': [statistics.median(gGBvideo.get_group(items)['dislikes/views(%)'].values) for items in dfGBcategory['id']],
    'median_comments/views(%)': [statistics.median(gGBvideo.get_group(items)['comments/views(%)'].values) for items in dfGBcategory['id']]
}

dfRelativeViewsGB = pd.DataFrame(data_relative_views_gb)
dfRelativeViewsGB
# Out:
#     id               category  \
# 0    1       Film & Animation
# 1    2       Autos & Vehicles
# 2   10                  Music
# 3   15         Pets & Animals
# 4   17                 Sports
# 5   19        Travel & Events
# 6   20                 Gaming
# 7   22         People & Blogs
# 8   23                 Comedy
# 9   24          Entertainment
# 10  25        News & Politics
# 11  26          Howto & Style
# 12  27              Education
# 13  28   Science & Technology
# 14  29  Nonprofits & Activism
# 15  43                  Shows
#
#                                        likes/views(%)  \
# 0   [0.3175904071520472, 3.0087111162613542, 4.008...
# 1   [2.321530233700521, 2.951955143474915, 3.52607...
# 2   [4.589074654725196, 4.874544880621789, 1.40005...
# 3   [4.535085125258755, 4.267171721490197, 4.14419...
# 4   [0.6934214781015341, 3.1269154027725254, 0.728...
# 5   [0.8797735906467975, 0.8098961658764778, 0.783...
# 6   [3.5250175596510287, 4.49717855838183, 1.20865...
# 7   [4.9226035710328375, 4.540078902942159, 1.3392...
# 8   [6.011147594855841, 8.591164682875684, 4.21307...
# 9   [2.4259893397315193, 4.4562998034283785, 1.723...
# 10  [0.3056546102903719, 0.6865528441218336, 7.255...
# 11  [0.7707230173928631, 2.705435820329522, 4.7877...
# 12  [4.114465641785515, 5.7265064498858855, 4.0346...
# 13  [3.353104520715317, 1.6824196597353496, 0.9748...
# 14  [6.974571873378308, 6.99060576611597, 6.737562...
# 15  [3.9469963374975485, 3.6997776670837936, 3.508...
#
#                                     dislikes/views(%)  \
# 0   [0.033605746260510744, 0.09105834087489091, 0....
# 1   [0.03180178402329481, 0.05680360611280097, 0.0...
# 2   [0.25305125791593813, 0.06288699950142619, 0.0...
# 3   [0.057501208698876725, 0.057288950073107546, 0...
# 4   [0.04311428879387777, 0.0867229170198615, 0.08...
# 5   [0.08802393257397814, 0.08266194174219017, 0.0...
# 6   [0.055550638644037156, 0.24701831762594792, 0....
# 7   [0.06433596947606127, 0.07312515234406738, 0.2...
# 8   [0.10066231293759856, 0.0719015945778429, 0.06...
# 9   [0.21772307598858046, 0.12098666272114308, 0.2...
# 10  [0.020376974019358125, 0.049151835919375254, 0...
# 11  [0.14183651082460205, 0.8958242547826636, 0.56...
# 12  [0.07853306167808853, 0.04889251977968197, 0.0...
# 13  [0.09672966154139097, 0.42428061331653016, 0.1...
# 14  [0.02594706798131811, 0.038872691933916424, 0....
# 15  [0.02668199170805796, 0.025311124340392097, 0....
#
#                                     comments/views(%)  median_likes/views(%)  \
# 0   [0.05150017983905746, 0.2362381251331226, 0.30...               1.769233
# 1   [0.11939866233745952, 0.4938248983032213, 0.19...               1.916856
# 2   [0.733638840372504, 0.25375241374574625, 0.136...               2.961296
# 3   [0.22179037640995314, 0.2037177963420578, 0.19...               2.860887
# 4   [0.13293572378112312, 0.14605964971766147, 0.7...               1.040391
# 5   [0.08797218423031325, 0.08102597148231175, 0.0...               1.287045
# 6   [0.6264982195549547, 1.8231985794439545, 0.222...               2.982085
# 7   [0.053598991926651844, 0.2753477958634636, 0.3...               3.387852
# 8   [0.5957287029064834, 0.3422661214105791, 0.318...               3.016924
# 9   [0.26166631233675514, 0.19724799729449813, 0.1...               2.322113
# 10  [0.3056546102903719, 0.11717797683179063, 1.26...               1.447201
# 11  [0.13120603943655731, 0.9683417770784754, 0.55...               4.000906
# 12  [0.5852935728838673, 0.4218356579228389, 0.560...               3.984285
# 13  [0.37219339585217626, 1.921865154379332, 0.375...               2.148762
# 14  [0.4929942916450441, 0.41788143828960156, 0.37...               2.259469
# 15  [0.39316028807429, 0.35789929817314425, 0.3347...               2.853041
#
#     median_dislikes/views(%)  median_comments/views(%)
# 0                   0.075178                  0.223538
# 1                   0.065944                  0.333949
# 2                   0.070168                  0.207589
# 3                   0.052298                  0.270536
# 4                   0.047584                  0.226159
# 5                   0.046868                  0.177006
# 6                   0.090257                  0.414793
# 7                   0.088221                  0.312567
# 8                   0.077529                  0.235624
# 9                   0.078000                  0.260793
# 10                  0.219019                  0.645302
# 11                  0.110756                  0.327455
# 12                  0.093905                  0.415833
# 13                  0.071505                  0.283237
# 14                  0.042493                  0.316321
# 15                  0.021970                  0.274771

# %% [markdown]
# ### 1C. Boxplotting Relative Value Likes/Views Data Video Great Britain

# %% [markdown]
# #### Berikut adalah hasil boxplot jumlah likes terhadap jumlah views di Great Britain

# %%
# sorting
dfRelativeViewsGB_sortLikes = dfRelativeViewsGB.sort_values(by="median_likes/views(%)",ascending=False)

fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfRelativeViewsGB_sortLikes['likes/views(%)'].values, showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori dfRelativeViewsGB
ax.set_xticklabels(dfRelativeViewsGB_sortLikes['category'], rotation='vertical')

# penamaan judul
plt.title("RELATIVE VALUE LIKES/VIEWS WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# ### 2C. Boxplotting Relative Value Dislikes/Views Data Video Great Britain

# %% [markdown]
# #### Berikut adalah hasil boxplot jumlah dislikes terhadap jumlah views di Great Britain

# %%
# sorting
dfRelativeViewsGB_sortDislikes = dfRelativeViewsGB.sort_values(by="median_dislikes/views(%)",ascending=False)

fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfRelativeViewsGB_sortDislikes['dislikes/views(%)'].values, showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori dfRelativeViewsGB
ax.set_xticklabels(dfRelativeViewsGB_sortDislikes['category'], rotation='vertical')

# penamaan judul
plt.title("RELATIVE VALUE DISLIKES/VIEWS WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %%
# sorting
dfRelativeViewsGB_sortComments = dfRelativeViewsGB.sort_values(by="median_comments/views(%)",ascending=False)

fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfRelativeViewsGB_sortComments['comments/views(%)'].values, showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori dfRelativeViewsGB
ax.set_xticklabels(dfRelativeViewsGB_sortComments['category'], rotation='vertical')

# penamaan judul
plt.title("RELATIVE VALUE COMMENTS/VIEWS WILAYAH GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b></b>

# %% [markdown]
# ## MENCARI PENYEBAB FIRST TRENDING DI GREAT BRITAIN

# %% [markdown]
# Di sini masing-masing datasets dari setiap region ditransform ulang dengan hanya mencantumkan data video pada saat pertama kali video tersebut mengalami trend

# %% [markdown]
# Dataframe baru dibuat dari masing-masing datasets dengan <b>grouping by video_id</b> lalu digunakan <b>loc</b> untuk melokasikan data berdasarkan index, lalu yang dicari adalah trending_date pertama kali, <b>maka dicari index terkecil dari masing-masing video_id berdasarkan trending_datenya dengan menggunakan idxmin()</b>

# %%
dfGBvideosFirstTrend = dfGBvideos.loc[dfGBvideos.groupby('video_id')['trending_date'].idxmin()][['video_id','trending_date','title','channel_title','category_id','publish_time','tags','views','likes','dislikes','comment_count']]

# %% [markdown]
# ### Sorting

# %% [markdown]
# Dilakukan reindex untuk masing-masing dataframe berdasarkan video_id dan trending_date nya

# %%
dfGBvideosFirstTrend = dfGBvideosFirstTrend.sort_values(by=['video_id','trending_date']).reset_index(drop=True)

# %% [markdown]
# #### DATA VIDEO FIRST TREND GREAT BRITAIN

# %% [markdown]
# Berikut adalah contoh dataframe video Great Britain setelah dimodifikasi dengan hanya menampilkan data-data video saat pertama kali masuk trending

# %%
dfGBvideosFirstTrend.head()
# Out:
#       video_id trending_date  \
# 0  --uXQQ0h-yQ    2017-12-25
# 1  -3VBPAZPTQI    2017-12-31
# 2  -43MBOJnVks    2018-02-14
# 3  -5WBCrazSfg    2017-11-29
# 4  -5aaJJQFvOg    2018-02-24
#
#                                                title          channel_title  \
# 0                    Paul McCartney - Pipes of Peace           PonteFractus
# 1   NEW YEAR'S EVE MAKEUP TUTORIAL | JAMIE GENEVIEVE        Jamie Genevieve
# 2                  RAMPAGE - OFFICIAL TRAILER 2 [HD]  Warner Bros. Pictures
# 3  Neymar will win the Ballon d'Or | Philippe Cou...              Soccer AM
# 4       Havana - swing cover | dodie feat. FLASHBACK            doddleoddle
#
#    category_id              publish_time  \
# 0           24  2008-11-24T17:59:52.000Z
# 1           22  2017-12-29T15:11:23.000Z
# 2           24  2018-02-13T17:00:07.000Z
# 3           17  2017-11-27T19:44:49.000Z
# 4           10  2018-02-21T22:01:06.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0             ww1|"great"|"war"|"trenches"|"tommies"   24723    216         3
# 1  jamie genevieve|"bblogger"|"youtuber"|"makeup"...  209192  11119       153
# 2  Rampage|"Rampage Movie"|"Rampage Trailer"|"War...  544638   7985       330
# 3  Soccer AM|"Football"|"Soccer"|"Premier League"...  172090   4354        53
# 4  havana|"cover"|"a capella"|"swing"|"dodie"|"fl...  509454  82757       842
#
#    comment_count
# 0             10
# 1            740
# 2           1038
# 3            587
# 4           4535

# %% [markdown]
# ### Boxplotting Viewer Data Video First Trend Great Britain

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend['views'].values)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT VIEWERS REGION GREAT BRITAIN", fontsize=14)

plt.ylabel("Jumlah Views", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Views')

# %% [markdown]
# ## Testing IQR Viewer Data Video First Trend Great Britain
# Step untuk mendeteksi outlier salah satunya adalah dengan menemukan range bawah dan atas dari suatu data dengan cara berikut :
# 1. Mengurutkan data dari nilai terendah
# 2. Menghitung Q1 (kuartil 1)
# 3. Menghitung Q3 (kuartil 3)
# 4. Menghitung IQR = (Q3 - Q1)
# 5. Menemukan range bawah data = Q1 -(1.5 * IQR)
# 6. Menemukan range atas data = Q3 + (1.5 * IQR)

# %% [markdown]
# 1. Mengurutkan data dari yang terendah

# %%
dfGBvideosFirstTrendSortViews = dfGBvideosFirstTrend.sort_values(by=['views'])

# %% [markdown]
# 2. Menghitung Q1 (kuartil 1)

# %%
Q1_GBFirstTrendView = dfGBvideosFirstTrendSortViews.views.quantile(0.25)

# %% [markdown]
# 3. Menghitung Q3 (kuartil 3)

# %%
Q3_GBFirstTrendView = dfGBvideosFirstTrendSortViews.views.quantile(0.75)

# %% [markdown]
# 4. Menghitung IQR = (Q3 - Q1)

# %%
IQR_GBFirstTrendView = Q3_GBFirstTrendView - Q1_GBFirstTrendView

# %% [markdown]
# 5. Menemukan range bawah data = Q1 -(1.5 * IQR)

# %%
lower_GBFirstTrendView = Q1_GBFirstTrendView - (1.5 * IQR_GBFirstTrendView)

# %% [markdown]
# 6. Menemukan range atas data = Q3 + (1.5 * IQR)

# %%
upper_GBFirstTrendView =  Q3_GBFirstTrendView + (1.5 * IQR_GBFirstTrendView)

# %% [markdown]
# <b>Berikut adalah hasil perhitungan yang telah dilakukan di atas</b>

# %%
print("IQR Great Britain")
print("IQR =", IQR_GBFirstTrendView)
print("Lower =", lower_GBFirstTrendView)
print("Upper =", upper_GBFirstTrendView)
# Out:
# IQR Great Britain
# IQR = 878130.25
# Lower = -1228350.625
# Upper = 2284170.375

# %%
dfGBvideosFirstTrend_IQRView = dfGBvideosFirstTrendSortViews[(dfGBvideosFirstTrendSortViews.views < upper_GBFirstTrendView) & (dfGBvideosFirstTrendSortViews.views > lower_GBFirstTrendView)]

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend_IQRView['views'].values)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT VIEWERS REGION GREAT BRITAIN SETELAH OUTLIER REMOVAL DENGAN IQR", fontsize=14)

plt.ylabel("Jumlah Views", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Views')

# %% [markdown]
# Di sini coba dilakukan boxplotting tanpa menampilkan outlier

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend_IQRView['views'].values, showfliers=False)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT VIEWERS REGION GREAT BRITAIN SETELAH OUTLIER REMOVAL DENGAN IQR", fontsize=14)

plt.ylabel("Jumlah Views", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Views')

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend['views'].values, showfliers=False)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT VIEWERS REGION GREAT BRITAIN TANPA REMOVAL DENGAN IQR", fontsize=14)

plt.ylabel("Jumlah Views", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Views')

# %% [markdown]
# ## STATISTIK DARI SETIAP KATEGORI YANG TERDAPAT DI DATAFRAME FIRST TREND VIDEO GREAT BRITAIN

# %%
# mengelompokan ulang dataframe videosFirstTrend berdasarkan id kategori
gGBVideoFtrend = dfGBvideosFirstTrend.groupby('category_id')

# %% [markdown]
# Membuat dataframe baru yang memiliki kolom id, category yang diambil dari dfGBcategory, dan views yang diambil dari hasil pengelompokkan berdasarkan category_id

# %% [markdown]
# data_ftrend_views_gb = {
#
#     # a adalah hasil sorting array saat menemukan value yang unique dari id kategori data video region Great Britain
#     'id' : a,
#     'category' : [i for i in dfGBcategory['category']],
#     'views': [gGBVideoFtrend.get_group(items)['views'].values for items in dfGBcategory['id']]
# }
#
# dfFtrendViewsGB = pd.DataFrame(data_ftrend_views_gb)
# dfFtrendViewsGB

# %% [markdown]
# Tetapi setelah menjalankan cell di atas ditemukan bahwa pada dataframe video first trend Great Britain tidak ditemukan id kategori '43' atau kategori Shows. Sedangkan di dataframe video Great Britain pada awalnya ada video dengan kategori '43' atau Shows.

# %% [markdown]
# Berikut adalah video dengan kategori 43 pada dataframe dfGBvideos :

# %%
dfGBvideos.loc[dfGBvideos['category_id'] == 43]
# Out:
#           video_id trending_date                         title  \
# 35574  JtIY1Naxg0M    2018-05-26  Game of Zones - S5E7: NBA 1K
# 38001  https://i.ytimg.com/vi/JtIY1Naxg0M/default.jpg              False
# 38180  https://i.ytimg.com/vi/JtIY1Naxg0M/default.jpg              False
# 38348  https://i.ytimg.com/vi/JtIY1Naxg0M/default.jpg              False
# 38520  https://i.ytimg.com/vi/JtIY1Naxg0M/default.jpg              False
# 38697  https://i.ytimg.com/vi/JtIY1Naxg0M/default.jpg              False
# 38866  https://i.ytimg.com/vi/JtIY1Naxg0M/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 35574             False                   False
# 35748             False                   False
# 35922             False                   False
# 36092             False                   False
# 36261             False                   False
# 36443             False                   False
# 36616             False                   False
# 36792             False                   False
# 36962             False                   False
# 37126             False                   False
# 37294             False                   False
# 37468             False                   False
# 37646             False                   False
# 37824             False                   False
# 38001             False                   False
# 38180             False                   False
# 38348             False                   False
# 38520             False                   False
# 38697             False                   False
# 38866             False                   False
#
#                                              description
# 35574  NBA rookies are roasting each other over a gam...
# 35748  NBA rookies are roasting each other over a gam...
# 35922  NBA rookies are roasting each other over a gam...
# 36092  NBA rookies are roasting each other over a gam...
# 36261  NBA rookies are roasting each other over a gam...
# 36443  NBA rookies are roasting each other over a gam...
# 36616  NBA rookies are roasting each other over a gam...
# 36792  NBA rookies are roasting each other over a gam...
# 36962  NBA rookies are roasting each other over a gam...
# 37126  NBA rookies are roasting each other over a gam...
# 37294  NBA rookies are roasting each other over a gam...
# 37468  NBA rookies are roasting each other over a gam...
# 37646  NBA rookies are roasting each other over a gam...
# 37824  NBA rookies are roasting each other over a gam...
# 38001  NBA rookies are roasting each other over a gam...
# 38180  NBA rookies are roasting each other over a gam...
# 38348  NBA rookies are roasting each other over a gam...
# 38520  NBA rookies are roasting each other over a gam...
# 38697  NBA rookies are roasting each other over a gam...
# 38866  NBA rookies are roasting each other over a gam...

# %% [markdown]
# Berikut adalah video dengan kategori 43 pada dataframe first trend dfFtrendViewsGB :

# %%
dfGBvideosFirstTrend.loc[dfGBvideosFirstTrend['category_id'] == 43]
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count]
# Index: []

# %%
dfGBvideosFirstTrend.loc[dfGBvideosFirstTrend['video_id'] == 'JtIY1Naxg0M']
# Out:
#          video_id trending_date                         title  \
# 1045  JtIY1Naxg0M    2018-05-25  Game of Zones - S5E7: NBA 1K
#
#         channel_title  category_id              publish_time  \
# 1045  Bleacher Report           17  2018-05-24T21:00:01.000Z
#
#                                                    tags   views  likes  \
# 1045  bleacher report|"br"|"nba"|"philadelphia 76ers...  445567  24409
#
#       dislikes  comment_count
# 1045       133           2680

# %% [markdown]
# Terlihat bahwa terdapat video dengan id "JtIY1Naxg0M" memiliki id kategori 43, sedangkan di dataframe first trend video dengan kategori 43 tidak ditemukan. Tetapi, video dengan id "JtIY1Naxg0M" ditemukan pada dataframe first trend dengan id kategori 17 dengan index 1045. Kemungkinan pengupload video mengubah kategori videonya setelah video tersebut masuk ke dalam YouTube Trending menjadi 43.
#
# Maka dari itu diputuskan untuk mengubah kategori video dengan id "JtIY1Naxg0M" menjadi kategori 43.

# %%
dfGBvideosFirstTrend.loc[1045,'category_id'] = 43

# %%
dfGBvideosFirstTrend.loc[dfGBvideosFirstTrend['video_id'] == 'JtIY1Naxg0M']
# Out:
#          video_id trending_date                         title  \
# 1045  JtIY1Naxg0M    2018-05-25  Game of Zones - S5E7: NBA 1K
#
#         channel_title  category_id              publish_time  \
# 1045  Bleacher Report           43  2018-05-24T21:00:01.000Z
#
#                                                    tags   views  likes  \
# 1045  bleacher report|"br"|"nba"|"philadelphia 76ers...  445567  24409
#
#       dislikes  comment_count
# 1045       133           2680

# %%
data_ftrend_views_gb = {
    
    'id' : [items for items in dfGBcategory['id']],
    'category' : [items for items in dfGBcategory['category']],
    'views': [gGBVideoFtrend.get_group(items)['views'].values for items in dfGBcategory['id']],
    'median_views': [statistics.median(gGBVideoFtrend.get_group(items)['views'].values) for items in dfGBcategory['id']]
}

dfFtrendViewsGB = pd.DataFrame(data_ftrend_views_gb)
dfFtrendViewsGB
# Out:
#     id               category  \
# 0    1       Film & Animation
# 1    2       Autos & Vehicles
# 2   10                  Music
# 3   15         Pets & Animals
# 4   17                 Sports
# 5   19        Travel & Events
# 6   20                 Gaming
# 7   22         People & Blogs
# 8   23                 Comedy
# 9   24          Entertainment
# 10  25        News & Politics
# 11  26          Howto & Style
# 12  27              Education
# 13  28   Science & Technology
# 14  29  Nonprofits & Activism
# 15  43                  Shows
#
#                                                 views  median_views
# 0   [42076, 80992, 4427381, 387911, 284180, 463086... 233240.000000
# 1   [36069, 1858, 1547142, 705169, 704363, 1865148... 591541.500000
# 2   [509454, 1092530, 237150, 441467, 190313, 8445... 558621.000000
# 3   [52968, 71637, 106298, 50131, 44889, 491427, 2... 158576.000000
# 4   [172090, 211408, 75357, 130027, 1624478, 15235... 204147.500000
# 5   [59546, 76351, 1775039, 89715, 3254, 253735, 4...  83033.000000
# 6   [387566, 1100530, 334664, 23274, 125010, 99578... 132174.000000
# 7   [209192, 513127, 227704, 1164201, 17036, 67069... 140560.000000
# 8   [234821, 855521, 665386, 771567, 170214, 29863... 360132.500000
# 9   [24723, 544638, 259047, 5040540, 287354, 15538... 334437.000000
# 10  [212414, 47064, 25649, 351912, 1805611, 223109... 120930.000000
# 11  [110614, 2414, 174780, 243420, 25796, 903796, ... 110424.000000
# 12  [215949, 811112, 610602, 8851, 231896, 133211,... 174725.000000
# 13  [188715, 3412680, 4794673, 47610, 55731, 11585... 247151.000000
# 14     [19270, 178845, 36245, 115931, 8041970, 56096]  86013.500000
# 15                                           [445567] 445567.000000

# %%
# sort
dfFtrendViewsGB_sort = dfFtrendViewsGB.sort_values(by="median_views",ascending=False)

fig = plt.figure(1, figsize=(15, 15))

ax = sns.boxplot(data = dfFtrendViewsGB_sort['views'].values, showfliers = False)
sns.set(style="whitegrid")

# penamaan x tick berdasarkan id kategori dfFtrendViewsGB_sort
ax.set_xticklabels(dfFtrendViewsGB_sort['category'], rotation='vertical')

# penamaan judul
plt.title("DATA JUMLAH VIEW BERDASARKAN KATEGORI DATA VIDEO FIRST TREND GREAT BRITAIN", fontsize=14)

# penamaan label
plt.xlabel("Kategori", fontsize=14)
plt.ylabel("Jumlah Viewer", fontsize=14)
# Out:
# Text(0, 0.5, 'Jumlah Viewer')

# %% [markdown]
# ##  D. BOXPLOTTING RELATIVE VALUE DATA VIDEO FIRST TREND GREAT BRITAIN
# Karena melakukan boxplotting terhadap absolute value untuk jumlah views, likes, dislikes, dan comments tidak dapat dilihat dengan baik karena data terlalu diverse. Maka diputgbkan untuk melakukan boxplotting likes, dislikes, dan comments terhadap views untuk setiap video kemudian dikalikan 100 agar range value terjaga mulai dari 0 hingga 100.

# %%
# Menambah kolom likes/views
dfGBvideosFirstTrend['likes/views(%)'] = dfGBvideosFirstTrend['likes']/dfGBvideosFirstTrend['views']*100

# %%
# Menambah kolom dislikes/views
dfGBvideosFirstTrend['dislikes/views(%)'] = dfGBvideosFirstTrend['dislikes']/dfGBvideosFirstTrend['views']*100

# %%
# Menambah kolom comments/views
dfGBvideosFirstTrend['comments/views(%)'] = dfGBvideosFirstTrend['comment_count']/dfGBvideosFirstTrend['views']*100

# %% [markdown]
# ### 1D. Plotting Likes/Views % First Trend Great Britain

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend['likes/views(%)'].values, showfliers = False)

# ax.set_ylim(0,1000)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT LIKES TERHADAP VIEWS REGION GREAT BRITAIN", fontsize=14)

plt.ylabel("LIKES TERHADAP VIEWS", fontsize=14)
# Out:
# Text(0, 0.5, 'LIKES TERHADAP VIEWS')

# %% [markdown]
# ### 2D. Plotting Disikes/Views % First Trend Great Britain

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend['dislikes/views(%)'].values, showfliers = False)

#ax.set_ylim(0,100)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT DISLIKES TERHADAP VIEWS REGION GREAT BRITAIN", fontsize=14)

plt.ylabel("DISLIKES TERHADAP VIEWS", fontsize=14)
# Out:
# Text(0, 0.5, 'DISLIKES TERHADAP VIEWS')

# %% [markdown]
# ### 3D. Plotting Comments/Views % First Trend

# %%
fig = plt.figure(1, figsize=(5, 5))

# membuat axes
ax = fig.add_subplot(111)

# boxplot
ax.boxplot(dfGBvideosFirstTrend['comments/views(%)'].values, showfliers = False)

#ax.set_ylim(0,100)
ax.set_xticklabels("")

# penamaan judul
plt.title("BOXPLOT COMMENTS TERHADAP VIEWS REGION GREAT BRITAIN", fontsize=14)

plt.ylabel("COMMENTS TERHADAP VIEWS", fontsize=14)
# Out:
# Text(0, 0.5, 'COMMENTS TERHADAP VIEWS')

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## MENCARI MACAM-MACAM TOP 5

# %% [markdown]
# ## TOP 5 KATEGORI DENGAN JUMLAH VIDEO TERTINGGI & TERENDAH YANG MASUK TRENDING DI GREAT BRITAIN

# %% [markdown]
# Untuk mencari top 5 kategori dengan jumlah video tertinggi dan terendah yang masuk trending, maka dataframe baru yang menampilkan berapa banyak video yang masuk trend berdasarkan kategori perlu untuk dibuat.

# %%
data_count_category_gb = {

    'id' : [items for items in dfGBcategory['id']],
    'category' : [items for items in dfGBcategory['category']],
    'video_count': [gGBvideo.get_group(items)['category_id'].count() for items in dfGBcategory['id']]
}

dfCatCountGB = pd.DataFrame(data_count_category_gb)

print("JUMLAH VIDEO YANG TRENDING BERDASARKAN KATEGORI GREAT BRITAIN")
dfCatCountGB
# Out:
# JUMLAH VIDEO YANG TRENDING BERDASARKAN KATEGORI GREAT BRITAIN
#     id               category  video_count
# 0    1       Film & Animation         2577
# 1    2       Autos & Vehicles          144
# 2   10                  Music        13754
# 3   15         Pets & Animals          534
# 4   17                 Sports         1907
# 5   19        Travel & Events           96
# 6   20                 Gaming         1788
# 7   22         People & Blogs         2926
# 8   23                 Comedy         1828
# 9   24          Entertainment         9124
# 10  25        News & Politics         1225
# 11  26          Howto & Style         1928
# 12  27              Education          457
# 13  28   Science & Technology          518
# 14  29  Nonprofits & Activism           90
# 15  43                  Shows           20

# %% [markdown]
# ### 1. TOP 5 KATEGORI DENGAN VIDEO TERTINGGI YANG TRENDING DI GREAT BRITAIN

# %%
#sorting tertinggi
top5gb_count_high = dfCatCountGB.nlargest(5, "video_count")

#reindex dari 1
top5gb_count_high.index = np.arange(1, len(top5gb_count_high) + 1)

print("TOP 5 KATEGORI DENGAN JUMLAH VIDEO TERTINGGI YANG TRENDING DI GREAT BRITAIN")
top5gb_count_high
# Out:
# TOP 5 KATEGORI DENGAN JUMLAH VIDEO TERTINGGI YANG TRENDING DI GREAT BRITAIN
#    id          category  video_count
# 1  10             Music        13754
# 2  24     Entertainment         9124
# 3  22    People & Blogs         2926
# 4   1  Film & Animation         2577
# 5  26     Howto & Style         1928

# %% [markdown]
# ### 2. TOP 5 KATEGORI DENGAN VIDEO TERTINGGI YANG TRENDING DI GREAT BRITAIN

# %%
#sorting terendah
top5gb_count_low = dfCatCountGB.sort_values('video_count').head(5)

#reindex dari 1
top5gb_count_low.index = np.arange(1, len(top5gb_count_low) + 1)

print("TOP 5 KATEGORI DENGAN JUMLAH VIDEO TERENDAH YANG TRENDING DI GREAT BRITAIN")
top5gb_count_low
# Out:
# TOP 5 KATEGORI DENGAN JUMLAH VIDEO TERENDAH YANG TRENDING DI GREAT BRITAIN
#    id               category  video_count
# 1  43                  Shows           20
# 2  29  Nonprofits & Activism           90
# 3  19        Travel & Events           96
# 4   2       Autos & Vehicles          144
# 5  27              Education          457

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## TOP 5 KATEGORI BERDASARKAN AVERAGE VIEW DI GREAT BRITAIN

# %% [markdown]
# Untuk mencari top 5 kategori video tertinggi dan terendah berdasarkan average view untuk tiap wilayah wilayah, maka dataframe baru yang menampilkan berapa average view berdasarkan kategori perlu untuk dibuat.

# %%
data_avgview_category_gb = {
    
    'id' : [items for items in dfGBcategory['id']],
    'category' : [items for items in dfGBcategory['category']],
    'average_views': [gGBvideo.get_group(items)['views'].mean() for items in dfGBcategory['id']]
}

dfCatAvgViewGB = pd.DataFrame(data_avgview_category_gb)

# %% [markdown]
# ### 1. Top 5 Kategori Dengan Average Views Tertinggi di Great Britain

# %%
#sorting tertinggi
top5GB_avgview_high = dfCatAvgViewGB.nlargest(5, "average_views")

#reindex dari 1
top5GB_avgview_high.index = np.arange(1, len(top5GB_avgview_high) + 1)

print("TOP 5 KATEGORI DENGAN AVERAGE VIEWS TERTINGGI DI GREAT BRITAIN")
top5GB_avgview_high
# Out:
# TOP 5 KATEGORI DENGAN AVERAGE VIEWS TERTINGGI DI GREAT BRITAIN
#    id               category   average_views
# 1  10                  Music 12444442.690781
# 2  29  Nonprofits & Activism  3919980.688889
# 3  24          Entertainment  3264607.961530
# 4   1       Film & Animation  3245132.955374
# 5  28   Science & Technology  3168703.196911

# %% [markdown]
# ### 2. Top 5 Kategori Dengan Average Views Terendah di Great Britain

# %%
#sorting terendah
top5GB_avgview_low = dfCatAvgViewGB.sort_values('average_views').head(5)

#reindex dari 1
top5GB_avgview_low.index = np.arange(1, len(top5GB_avgview_low) + 1)

print("TOP 5 KATEGORI DENGAN AVERAGE VIEWS TERENDAH DI GREAT BRITAIN")
top5GB_avgview_low
# Out:
# TOP 5 KATEGORI DENGAN AVERAGE VIEWS TERENDAH DI GREAT BRITAIN
#    id         category  average_views
# 1  26    Howto & Style  617300.428942
# 2  27        Education  972189.402626
# 3  20           Gaming  976856.561521
# 4  15   Pets & Animals 1013708.938202
# 5  25  News & Politics 1150311.326531

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## TOP 5 CHANNEL DENGAN VIEWER TERBANYAK DI GREAT BRITAIN

# %%
#membuat dataframe baru dengan sum yang menghitung total viewer berdasarkan channel_title dalam datasets dfGBvideos
dfChannelViewGB = dfGBvideos.groupby(['channel_title'])['views'].sum().reset_index()

#melakukan sorting berdasarkan views
dfChannelViewGB.sort_values(by="views", inplace = True, ascending = False)

#reset index dari 1
dfChannelViewGB.reset_index(drop = True, inplace = True)
dfChannelViewGB.index = dfChannelViewGB.index + 1

dfChannelViewGB.head(5)
# Out:
#          channel_title       views
# 1           NickyJamTV  8516190092
# 2                Ozuna  8305198063
# 3            Bad Bunny  6891280759
# 4            DrakeVEVO  6581834413
# 5  ChildishGambinoVEVO  6101309613

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## TOP 5 CHANNEL YANG PALING SERING MASUK DAILY TRENDING DI GREAT BRITAIN

# %% [markdown]
# Untuk mencari top 5 channel yang <b>paling sering masuk</b> daily trending di tiap wilayah + berapa <b>total viewernya</b>, maka dataframe baru yang menampilkan berapa kali channel muncul di datasets videos masing-masing wilayah perlu untuk dibuat, kemudian dimerge dengan dataframe baru juga yang menampilkan berapa jumlah total viewer tiap channel yang videonya pernah masuk ke dalam daily trending.

# %%
#membuat dataframe baru dengan value_counts yang menghitung berapa kali channel_title muncul dalam datasets dfGBvideos
dfChannelCountGB = pd.DataFrame(dfGBvideos.channel_title.value_counts().reset_index())

#reset index dari 1
dfChannelCountGB.index = dfChannelCountGB.index + 1

#rename kolom
dfChannelCountGB.columns = ['channel_title', 'trending_count']

dfChannelCountGB.head(5)
# Out:
#                             channel_title  trending_count
# 1  The Tonight Show Starring Jimmy Fallon             208
# 2                       Jimmy Kimmel Live             207
# 3                            TheEllenShow             207
# 4                     Saturday Night Live             206
# 5                                     WWE             205

# %%
#membuat dataframe baru yang merupakan hasil merge dari dfChannelCountGB dan dfChannelViewGB berdasarkan channel_title
dfTop5ChannelGB = pd.merge(dfChannelCountGB,dfChannelViewGB, on="channel_title").reset_index(drop = True)

#melakukan index ulang dari angka 1
dfTop5ChannelGB.index = dfTop5ChannelGB.index + 1      

print("TOP 5 CHANNEL YANG MASUK DAILY TRENDING DI GREAT BRITAIN")
dfTop5ChannelGB.head(5)
# Out:
# TOP 5 CHANNEL YANG MASUK DAILY TRENDING DI GREAT BRITAIN
#                             channel_title  trending_count      views
# 1  The Tonight Show Starring Jimmy Fallon             208  447390019
# 2                       Jimmy Kimmel Live             207  398235069
# 3                            TheEllenShow             207  351577266
# 4                     Saturday Night Live             206  594799179
# 5                                     WWE             205  587090246

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</b>

# %% [markdown]
# ## TOP 5 VIDEO YANG PALING SERING MASUK DAILY TRENDING GREAT BRITAIN

# %% [markdown]
# Untuk mencari top 5 video yang paling sering masuk daily trending di tiap wilayah wilayah, maka dataframe baru yang menampilkan berapa kali video muncul di datasets Videos tersebut perlu untuk dibuat.
#
# #### Di sini size() digunakan untuk menghitung suatu elemen pada dataframe, tetapi jika size() dikombinasikan dengan groupby() , maka size akan bertindak seperti count() yang menghitung kolom yang di-groupby-kan

# %%
#membuat dataframe baru dengan size() yang menghitung berapa kali video_id & title muncul dalam datasets dfGBvideos
dfTop5VideoGB = dfGBvideos.groupby(["video_id", "title","category_id"]).size().reset_index(name="count")

#sorting berdasarkan count
dfTop5VideoGB.sort_values(by="count", inplace = True, ascending = False)

#reset index dari 1
dfTop5VideoGB.reset_index(drop = True, inplace = True)
dfTop5VideoGB.index = dfTop5VideoGB.index + 1

print("TOP 5 VIDEO YANG MASUK DAILY TRENDING DI GREAT BRITAIN")
dfTop5VideoGB.head(5)
# Out:
# TOP 5 VIDEO YANG MASUK DAILY TRENDING DI GREAT BRITAIN
#       video_id                                              title  \
# 1  NooW_RbfdWI  Jurassic World: Fallen Kingdom - Official Trai...
# 2  2z3EUY1aXdY  Justin Timberlake’s FULL Pepsi Super Bowl LII ...
# 3  BhIEIO0vaBE                                    To Our Daughter
# 4  Il-an3K9pjg                 Anne-Marie - 2002 [Official Video]
# 5  Q17z9a03YaM           Rich Brian - Cold (Official Music Video)
#
#    category_id  count
# 1           24     38
# 2           17     38
# 3           22     38
# 4           10     38
# 5           24     37
